# %%
# %load_ext autoreload
# %autoreload 2

# %%
"""Computing the score 
    score(e;q,m) = P (e|q,m) ∝ P (e|m)P (q|e) 
"""
from termcolor import colored
from tabulate import tabulate
import pickle5 as pickle

import time
from dkoulinker.entity_linker import EntityLinker, get_mentions_ner
from flair.models import SequenceTagger
from dkoulinker.entity_ranking import DictionaryRanking, QueryEntityRanking
from dkoulinker.utils import _print_colorful_text

# %%
#loading dicitonary of commonness,
print('Loading mention2pem dictionary ...')
handle = open('../data/pem/pem.pickle', 'rb')
mention2pem = pickle.load(handle)


print('Loading entity description dictionary ...')
handle_desc = open('../data/pem/entity2description.pickle', 'rb')
entity2description = pickle.load(handle_desc)
print('NUmber of entities: ', len(entity2description))

print('Loading dictionary of term frequency ...')
handle_desc = open('../data/pem/mention_freq.pickle', 'rb')
mention2freq = pickle.load(handle_desc)
print('Number of term in the collection: ', len(mention2freq))

#given by create_term_req
collection_size_terms = len(mention2pem)
# Out:
# Loading mention2pem dictionary ...
# Loading entity description dictionary ...
# NUmber of entities:  2680002
# Loading dictionary of term frequency ...
# Number of term in the collection:  3506008

# %%
list(mention2pem['reproduction'].keys())
# Out:
# ['GO:0000003']

# %%
list(mention2pem['reproduction'].values())
# Out:
# [1.0]

# %%
entity2description['GO:0005578']
# Out:
# '#UNK'

# %%
entity2description['GO:0031012']
# Out:
# ('structure',
#  'cells',
#  'biochemical',
#  'tissues',
#  'biomechanical',
#  'lying',
#  'proteinaceous',
#  'structural',
#  'extracellular',
#  'support',
#  'matrisome',
#  'cues',
#  'matrix',
#  'external',
#  'provides')

# %%
# load the NER tagger
tagger = SequenceTagger.load(
    '../resources/taggers/sota-ner-flair/best-model.pt')
# Out:
# 2021-12-14 16:40:33,002 loading file ../resources/taggers/sota-ner-flair/best-model.pt

# %%
text='quaternary ammonium salt that is the monoiodide. sexual reproduction'
get_mentions_ner(text,tagger)
# Out:
# (['quaternary ammonium salt'],
#  [{'text': 'quaternary ammonium salt', 'start_pos': 0, 'end_pos': 24}])

# %%
dictionarysearch_strategy = DictionaryRanking(mention2pem) 
queryranking_strategy = QueryEntityRanking(
    entity2description=entity2description,
    mention_freq=mention2freq,
    mention2pem=mention2pem,
    p_t_thetae_method = 'bayesian' #Smoothing method
    )
e_linker = EntityLinker(
    ranking_strategy=queryranking_strategy,
    entity2description=entity2description,
    ner_model=tagger,
    mention2pem=mention2pem,
    prune_overlapping_method='large_text',
    use_ner_dict=True

    )

# %%
def search():
    e_linker.get_mentions_by_tokens_and_dict(
        'a quaternary ammonium salt that is the monoiodide')

# %%
# %%time
search()
# Out:
# CPU times: user 67 µs, sys: 330 µs, total: 397 µs
# Wall time: 401 µs

# %%
# %timeit search()
# Out:
# 23 µs ± 230 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
text = 'a quaternary ammonium salt that is the monoiodide'
samples = e_linker.link_entities(text)

# %%
samples
# Out:
# [{'end_pos': 26,
#   'start_pos': 2,
#   'text': 'quaternary ammonium salt',
#   'entities': [['CHEBI:35273',
#     2.3198381271481447,
#     'hydrogens nitrogen salt bonded quaternary ammonium salts nh4(+))y(- univalent organyl compounds replaced usually groups compound derivatives']],
#   'best_entity': ('CHEBI:35273', 2.3198381271481447)}]

# %%
_print_colorful_text(text,samples)
# samples
# Out:
# a quaternary ammonium salt that is the monoiodide

# %%
text = 'Altered gut microbiome composition in HIV infection: causes, effects and potential intervention.'
samples = e_linker.link_entities(text)
_print_colorful_text(text, samples)
# Out:
# Altered gut microbiome composition in HIV infection: causes, effects and potential intervention.

# %%
import json

# %%
jsonStr = json.dumps(samples)
print(jsonStr)
# Out:
# [{"start_pos": 8, "end_pos": 11, "text": "gut", "entities": [["UBERON:0001007", 0.8700926733965282, "organs gastrointestinal tract devoted food residual digestion anatomical parts ingestion discharge assimilation digestive alimentary gut wastes system"], ["UBERON:0001555", 0.7340052681185107, "anus tract digestive mouth alimentary canal enteric extending gut tube"], ["UBERON:0004907", 0.36037230161509565, "gi gastrointestinal tract intestines definition region digestive lower beginning extending gut anus[go"], ["MA:0000917", 0.23101364089906892, "gut"], ["ZFA:0000112", 0.3708896865541044, "organs tract associated alimentary digestive canal enteric gut tube"]], "best_entity": ["UBERON:0001007", 0.8700926733965282]}, {"end_pos": 22, "text": "microbiome", "start_pos": 12, "entities": [["EFO:0004982", 3.4203408798620867, "microbiome microorganisms collectivity collection"]], "best_entity": ["EFO:0004982", 3.4203408798620867]}, {"end_pos": 34, "start_pos": 23, "text": "composition", "entities": [["PATO:0000025", 2.2103041492871944, "single structure quantities composed composition virtue relative ratios content inhering entity physical compositionality subparts bearer"]], "best_entity": ["PATO:0000025", 2.2103041492871944]}, {"end_pos": 51, "start_pos": 42, "text": "infection", "entities": [["EFO:0000544", 2.5152140094765976, "infection"], ["EFO:0005741", 593.7205574018384, "indirect direct diseases viral presence agent infectious disorder manifestations clinical parasitic resulting activity microbial transmitted disease communicable contact transmissible infection"]], "best_entity": ["EFO:0005741", 593.7205574018384]}, {"end_pos": 95, "start_pos": 83, "text": "intervention", "entities": [["EFO:0002571", 2.0669619323475756, "procedures preventive interventional encompasses patient intended behavioral interventiondescription procedure environmental surgical produces course acts intervention strategies general term activity population palliative medical therapeutic alter effects effect disease social"]], "best_entity": ["EFO:0002571", 2.0669619323475756]}]

# %%
from dkoulinker.utils import create_html_entities

# %%
text = 'a quaternary ammonium salt that is the monoiodide'
samples = e_linker.link_entities(text)
create_html_entities(text, samples)
# Out:
# '<div class="entities" style="line-height: 2.5 direction: ltr">a <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">quaternary ammonium salt <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CHEBI:35273</span> </mark>\n     that is the monoiodide</div>'

# %%
samples
# Out:
# [{'end_pos': 26,
#   'start_pos': 2,
#   'text': 'quaternary ammonium salt',
#   'entities': [['CHEBI:35273',
#     117.02924314033649,
#     'hydrogens nitrogen salt bonded quaternary ammonium salts nh4(+))y(- univalent organyl compounds replaced usually groups compound derivatives']],
#   'best_entity': ('CHEBI:35273', 117.02924314033649)}]

# %%
text='sexual reproduction'
samples = e_linker.get_mentions_by_tokens_and_dict(text)
_print_colorful_text(text, samples)
# Out:
# sexual reproduction

# %%
text='Quaternary ammonium salt that is the monoiodide'
samples = e_linker.get_mentions_by_tokens_and_dict(text)
_print_colorful_text(text, samples)
samples
# Out:
# Quaternary ammonium salt that is the monoiodide
# [{'text': 'ammonium', 'start_pos': 11, 'end_pos': 19},
#  {'text': 'salt', 'start_pos': 20, 'end_pos': 24}]

# %%
text = 'Quaternary ammonium salt that is the monoiodide. Sexual reproduction'
mentions = e_linker.link_entities(text)
_print_colorful_text(text, mentions)
mentions
# Out:
# Quaternary ammonium salt that is the monoiodide. Sexual reproduction
# [{'start_pos': 11,
#   'text': 'ammonium',
#   'end_pos': 19,
#   'entities': [['CHEBI:28938',
#     1.3237396584364176,
#     'protonation ammonia + nh4(+ nh4 ammonium ammonium(1 onium nh4](+ ion azanium cation obtained']],
#   'best_entity': ('CHEBI:28938', 1.3237396584364176)},
#  {'text': 'salt',
#   'start_pos': 20,
#   'end_pos': 24,
#   'entities': [['CHEBI:26710', 0.37499625005624904, 'sodium chloride'],
#    ['CHEBI:24866',
#     209.1498204223953,
#     'sel sels salt anions ionic salze salts compounds cations assembly compound sal salz sales']],
#   'best_entity': ('CHEBI:24866', 209.1498204223953)},
#  {'start_pos': 56,
#   'end_pos': 68,
#   'text': 'reproduction',
#   'entities': [['GO:0000003',
#     1.348232971990509,
#     'process inherited material genetic reproductive individuals contain production parent organisms reproduction new physiological portion']],
#   'best_entity': ('GO:0000003', 1.348232971990509)}]

# %%
text='quaternary ammonium salt that is the monoiodide that can be found in some species with sexual reproduction reduced'
mentions = e_linker.link_entities(text)
_print_colorful_text(text, mentions)
mentions
# Out:
# quaternary ammonium salt that is the monoiodide that can be found in some species with sexual reproduction reduced
# [{'start_pos': 0,
#   'text': 'quaternary ammonium salt',
#   'end_pos': 24,
#   'entities': [['CHEBI:35273',
#     1.4534579639500007,
#     'hydrogens nitrogen salt bonded quaternary ammonium salts nh4(+))y(- univalent organyl compounds replaced usually groups compound derivatives']],
#   'best_entity': ('CHEBI:35273', 1.4534579639500007)},
#  {'start_pos': 74,
#   'end_pos': 81,
#   'text': 'species',
#   'entities': [['OBI:0100026', 0.9987614057151663, 'organism'],
#    ['MCCV_000003', 0.0012359720987304887, 'species'],
#    ['NCBITaxon:species', 0.0006179860493652444, 'species']],
#   'best_entity': ('OBI:0100026', 0.9987614057151663)},
#  {'end_pos': 106,
#   'text': 'reproduction',
#   'start_pos': 94,
#   'entities': [['GO:0000003',
#     1.2203838511657648,
#     'process inherited material genetic reproductive individuals contain production parent organisms reproduction new physiological portion']],
#   'best_entity': ('GO:0000003', 1.2203838511657648)},
#  {'start_pos': 107,
#   'text': 'reduced',
#   'end_pos': 114,
#   'entities': [['PATO:0000587',
#     0.7560367047862533,
#     'low reduced decreased relatively tiny small quality underdeveloped hypoplasia size'],
#    ['PATO:0001997',
#     0.5040244698575023,
#     'low reduced decreased relatively subnumerary fewer present number organism numbers']],
#   'best_entity': ('PATO:0000587', 0.7560367047862533)}]

# %%
text = 'quaternary ammonium salt that is the monoiodide that can be found in some species with reduced sexual reproduction'
mentions = e_linker.link_entities(text)
_print_colorful_text(text, mentions)
# Out:
# quaternary ammonium salt that is the monoiodide that can be found in some species with reduced sexual reproduction

# %%
text='A molecular entity having a net electric.'
mentions = e_linker.link_entities(text)
_print_colorful_text(text, mentions)
mentions
# Out:
# mention net
# P(e|m) 1.0
# P(q|e) 6.664883535521932
# mention entity
# P(e|m) 0.9901477832512315
# P(q|e) 4.529518130742791
# mention entity
# P(e|m) 0.4187192118226601
# P(q|e) 4.529518130742791
# mention molecular entity
# P(e|m) 1.0
# P(q|e) 2.667553377723604
#
# A molecular entity having a net electric.
# [{'text': 'molecular entity',
#   'end_pos': 18,
#   'start_pos': 2,
#   'entities': [['CHEBI:23367',
#     2.667553377723604,
#     'separately entite complex entities entidades pair entidad moleculaire radical entitaet molekulare distinct constitutionally distinguishable entity molecule isotopically molecular identifiable atom conformer ion etc moleculares']],
#   'best_entity': ('CHEBI:23367', 2.667553377723604)},
#  {'start_pos': 28,
#   'end_pos': 31,
#   'text': 'net',
#   'entities': [['GO:0140644',
#     6.664883535521932,
#     'granular structure microorganisms dna microbicidal composed entrapped nuclear net granule antimicrobial framework damage chromatin extracellular neutrophil associated proteins trap histones']],
#   'best_entity': ('GO:0140644', 6.664883535521932)}]

# %%
text="there's a molecular entity with electric charge"
mentions = e_linker.link_entities(text)
_print_colorful_text(text, mentions)
mentions
# Out:
# there's a molecular entity with electric charge
# [{'end_pos': 26,
#   'start_pos': 10,
#   'text': 'molecular entity',
#   'entities': [['CHEBI:23367',
#     1.0405706682529128,
#     'separately entite complex entities entidades pair entidad moleculaire radical entitaet molekulare distinct constitutionally distinguishable entity molecule isotopically molecular identifiable atom conformer ion etc moleculares']],
#   'best_entity': ('CHEBI:23367', 1.0405706682529128)}]

# %%
text = "theres a molecular entity with electric charge"
mentions = e_linker.link_entities(text)
_print_colorful_text(text, mentions)
mentions
# Out:
# theres a molecular entity with electric charge
# [{'end_pos': 25,
#   'start_pos': 9,
#   'text': 'molecular entity',
#   'entities': [['CHEBI:23367',
#     1.0322774021456191,
#     'separately entite complex entities entidades pair entidad moleculaire radical entitaet molekulare distinct constitutionally distinguishable entity molecule isotopically molecular identifiable atom conformer ion etc moleculares']],
#   'best_entity': ('CHEBI:23367', 1.0322774021456191)}]

# %%
text = 'The fluoride salt of beryllium (+2 oxidation state). In the solid state it exists as a glass, with four-coordinate Be(2+) tetrahedral centres and two-coordinate fluoride centres. As a gas it adopts a linear triatomic structure and in the liquid state a fluctuating tetrahedral structure. In protein crystallography it is used as a mimic of phosphate.'
mentions = e_linker.link_entities(text)
_print_colorful_text(text, mentions)
mentions
# Out:
# The fluoride salt of beryllium (+2 oxidation state). In the solid state it exists as a glass, with four-coordinate Be(2+) tetrahedral centres and two-coordinate fluoride centres. As a gas it adopts a linear triatomic structure and in the liquid state a fluctuating tetrahedral structure. In protein crystallography it is used as a mimic of phosphate.
# [{'text': 'fluoride salt',
#   'end_pos': 17,
#   'start_pos': 4,
#   'entities': [['CHEBI:24060',
#     1.143864044958866,
#     'fluoride salt salts fluorides']],
#   'best_entity': ('CHEBI:24060', 1.143864044958866)},
#  {'text': 'beryllium',
#   'start_pos': 21,
#   'end_pos': 30,
#   'entities': [['CHEBI:33783',
#     0.3570234448946624,
#     'ben metallic be(0 metal beryllium(0 beryllium'],
#    ['CHEBI:30501',
#     0.7140326101366956,
#     'alkaline earth 4be atomic atom 4 metal number beryllium berilio']],
#   'best_entity': ('CHEBI:30501', 0.7140326101366956)},
#  {'start_pos': 45,
#   'text': 'state',
#   'end_pos': 50,
#   'entities': [['SIO:000662', 1.1365954796019202, 'state']],
#   'best_entity': ('SIO:000662', 1.1365954796019202)},
#  {'end_pos': 65,
#   'text': 'solid',
#   'start_pos': 60,
#   'entities': [['PATO:0001736',
#     1.0949066013404958,
#     'configuration having quality arrangement virtue parts characteristics exhibits inhering solid solids physical bearer']],
#   'best_entity': ('PATO:0001736', 1.0949066013404958)},
#  {'end_pos': 71,
#   'text': 'state',
#   'start_pos': 66,
#   'entities': [['SIO:000662', 1.1365954796019202, 'state']],
#   'best_entity': ('SIO:000662', 1.1365954796019202)},
#  {'text': 'glass',
#   'start_pos': 87,
#   'end_pos': 92,
#   'entities': [['CHEBI:131189',
#     1.1365272906919734,
#     'amorphous polymerous sodium transparent glass oxides brittle inorganic silicate basic usually hard potassium']],
#   'best_entity': ('CHEBI:131189', 1.1365272906919734)},
#  {'text': 'coordinate',
#   'start_pos': 104,
#   'end_pos': 114,
#   'entities': [['SIO:000071', 1.0661323370046794, 'coordinate']],
#   'best_entity': ('SIO:000071', 1.0661323370046794)},
#  {'end_pos': 160,
#   'text': 'coordinate',
#   'start_pos': 150,
#   'entities': [['SIO:000071', 1.0661323370046794, 'coordinate']],
#   'best_entity': ('SIO:000071', 1.0661323370046794)},
#  {'text': 'fluoride',
#   'end_pos': 169,
#   'start_pos': 161,
#   'entities': [['CHEBI:17051',
#     0.8616904512144125,
#     'fluorine f- fluoride(1- ion f(- fluoride anion'],
#    ['CHEBI:29228',
#     0.2154107663664717,
#     "hydrofluoric d'hydrogene bonded atoms containing fluoride diatomic covalently fluorure molecule fluorane acid fluorine fluoridohydrogen hydrogen hf hydrogenfluorid fluorwasserstoff"]],
#   'best_entity': ('CHEBI:17051', 0.8616904512144125)},
#  {'end_pos': 187,
#   'text': 'gas',
#   'start_pos': 184,
#   'entities': [['GO:0034005',
#     0.5548967993511591,
#     'reaction -(r)-germacrene farnesyl germacrene forming -(10r)-germacrene = gas catalysis synthase -germacrene diphosphate activity trans 2 + trans,6 lyase'],
#    ['PATO:0001737',
#     0.5549078956227067,
#     'configuration having quality arrangement virtue parts characteristics exhibits gas inhering gaseus physical gases bearer']],
#   'best_entity': ('PATO:0001737', 0.5549078956227067)},
#  {'end_pos': 206,
#   'text': 'linear',
#   'start_pos': 200,
#   'entities': [['PATO:0001199',
#     1.0710489152050435,
#     'opposite quality narrow virtue inhering margins linear parallel shape bearer']],
#   'best_entity': ('PATO:0001199', 1.0710489152050435)},
#  {'text': 'structure',
#   'start_pos': 217,
#   'end_pos': 226,
#   'entities': [['PATO:0000141',
#     0.92912340567383,
#     'structure morphology quality form arrangements connectivity virtue relative relational position organism parts inhering pattern conformation structural shape underlying bearer'],
#    ['SIO:000600', 0.6637193015582872, 'structure']],
#   'best_entity': ('PATO:0000141', 0.92912340567383)},
#  {'text': 'liquid',
#   'start_pos': 238,
#   'end_pos': 244,
#   'entities': [['PATO:0001735', 1.1365897967239729, 'configuration liquid']],
#   'best_entity': ('PATO:0001735', 1.1365897967239729)},
#  {'end_pos': 250,
#   'text': 'state',
#   'start_pos': 245,
#   'entities': [['SIO:000662', 1.1365954796019202, 'state']],
#   'best_entity': ('SIO:000662', 1.1365954796019202)},
#  {'start_pos': 253,
#   'end_pos': 264,
#   'text': 'fluctuating',
#   'entities': [['PATO:0002374',
#     1.1365784312237976,
#     'fluctuating alteration cyclic recurrent']],
#   'best_entity': ('PATO:0002374', 1.1365784312237976)},
#  {'text': 'structure',
#   'start_pos': 277,
#   'end_pos': 286,
#   'entities': [['PATO:0000141',
#     0.92912340567383,
#     'structure morphology quality form arrangements connectivity virtue relative relational position organism parts inhering pattern conformation structural shape underlying bearer'],
#    ['SIO:000600', 0.6637193015582872, 'structure']],
#   'best_entity': ('PATO:0000141', 0.92912340567383)},
#  {'start_pos': 291,
#   'end_pos': 298,
#   'text': 'protein',
#   'entities': [['CHEBI:16541',
#     0.19135146724784283,
#     'chains synthesized occurring naturally protein chain ribosome polypeptide'],
#    ['CHEBI:36080',
#     11.385298457938752,
#     'biological synthesized proteins protein macromolecule consisting chain minimally ribosome polypeptide'],
#    ['PR:000000001', 73.76857236271829, 'protein'],
#    ['SIO:010043', 0.191358164365028, 'protein']],
#   'best_entity': ('PR:000000001', 73.76857236271829)},
#  {'text': 'phosphate',
#   'end_pos': 349,
#   'start_pos': 340,
#   'entities': [['CHEBI:35780',
#     0.38242071307857206,
#     'oxoanion base conjugate phosphorus ion pi phosphoric phosphate ions acid'],
#    ['CHEBI:18367',
#     0.21852393674924261,
#     'hydrogenphosphate base conjugate tetraoxidophosphate(3- po4](3- tetraoxophosphate(v orthophosphate ion phosphate(3- po4(3- tetraoxophosphate(3- phosphate'],
#    ['CHEBI:43474',
#     0.1092597834629903,
#     'hydrogenphosphate base hydrogentetraoxophosphate(v po3(oh)](2- hydrogen(tetraoxidophosphate)(2- dihydrogenphosphate hydrogentetraoxophosphate(2- hpo4(2- inorganic p(oh)o3](2- group conjugate hydroxidotrioxidophosphate(2- ion hydrogen phosphate'],
#    ['CHEBI:26020',
#     76.58995955056291,
#     'anionic analogues entities coordination describe salts chemistry phosphates esters inorganic term acids atom central phosphorus chalcogen phosphoric phosphate oligophosphoric'],
#    ['CHEBI:26078',
#     0.10925432175731455,
#     'phosphorsaeure oxo phosphorique phosphoricum tetraoxophosphate(3- acidum oxoacid trihydrogen acide po(oh)3 orthophosphoric tetraoxophosphoric covalently groups acid hydroxy phosphorsaeureloesungen trihydroxidooxidophosphorus atom joined central phosphorus phosphoric phosphate h3po4 consists']],
#   'best_entity': ('CHEBI:26020', 76.58995955056291)}]

# %%
text = 'The fluoride salt of beryllium (+2 oxidation state)'
mentions = e_linker.link_entities(text)
_print_colorful_text(text, mentions)
mentions
# Out:
# The fluoride salt of beryllium (+2 oxidation state)
# [{'text': 'fluoride salt',
#   'end_pos': 17,
#   'start_pos': 4,
#   'entities': [['CHEBI:24060',
#     1.7120736865784845,
#     'fluoride salt salts fluorides']],
#   'best_entity': ('CHEBI:24060', 1.7120736865784845)},
#  {'text': 'beryllium',
#   'start_pos': 21,
#   'end_pos': 30,
#   'entities': [['CHEBI:33783',
#     0.4387205048735839,
#     'ben metallic be(0 metal beryllium(0 beryllium'],
#    ['CHEBI:30501',
#     0.8774209557861625,
#     'alkaline earth 4be atomic atom 4 metal number beryllium berilio']],
#   'best_entity': ('CHEBI:30501', 0.8774209557861625)},
#  {'start_pos': 45,
#   'text': 'state',
#   'end_pos': 50,
#   'entities': [['SIO:000662', 1.6688984143375813, 'state']],
#   'best_entity': ('SIO:000662', 1.6688984143375813)}]

# %%
text='In the solid state it exists as a glass, with four-coordinate Be(2+) tetrahedral centres and two-coordinate fluoride centres.'
mentions = e_linker.link_entities(text)
_print_colorful_text(text, mentions)
mentions
# Out:
# In the solid state it exists as a glass, with four-coordinate Be(2+) tetrahedral centres and two-coordinate fluoride centres.
# [{'text': 'solid',
#   'end_pos': 12,
#   'start_pos': 7,
#   'entities': [['PATO:0001736',
#     1.259733685544236,
#     'configuration having quality arrangement virtue parts characteristics exhibits inhering solid solids physical bearer']],
#   'best_entity': ('PATO:0001736', 1.259733685544236)},
#  {'text': 'state',
#   'start_pos': 13,
#   'end_pos': 18,
#   'entities': [['SIO:000662', 1.3853066100438254, 'state']],
#   'best_entity': ('SIO:000662', 1.3853066100438254)},
#  {'text': 'glass',
#   'end_pos': 39,
#   'start_pos': 34,
#   'entities': [['CHEBI:131189',
#     1.3852310552144478,
#     'amorphous polymerous sodium transparent glass oxides brittle inorganic silicate basic usually hard potassium']],
#   'best_entity': ('CHEBI:131189', 1.3852310552144478)},
#  {'text': 'coordinate',
#   'end_pos': 61,
#   'start_pos': 51,
#   'entities': [['SIO:000071', 1.1770515550615042, 'coordinate']],
#   'best_entity': ('SIO:000071', 1.1770515550615042)},
#  {'text': 'coordinate',
#   'start_pos': 97,
#   'end_pos': 107,
#   'entities': [['SIO:000071', 1.1770515550615042, 'coordinate']],
#   'best_entity': ('SIO:000071', 1.1770515550615042)},
#  {'end_pos': 116,
#   'start_pos': 108,
#   'text': 'fluoride',
#   'entities': [['CHEBI:17051',
#     0.9665726788116387,
#     'fluorine f- fluoride(1- ion f(- fluoride anion'],
#    ['CHEBI:29228',
#     0.2416310893564668,
#     "hydrofluoric d'hydrogene bonded atoms containing fluoride diatomic covalently fluorure molecule fluorane acid fluorine fluoridohydrogen hydrogen hf hydrogenfluorid fluorwasserstoff"]],
#   'best_entity': ('CHEBI:17051', 0.9665726788116387)}]

# %%
text = ' As a gas it adopts a linear triatomic structure and in the liquid state a fluctuating tetrahedral structure.'
mentions = e_linker.link_entities(text)
_print_colorful_text(text, mentions)
mentions
# Out:
#  As a gas it adopts a linear triatomic structure and in the liquid state a fluctuating tetrahedral structure.
# [{'start_pos': 6,
#   'text': 'gas',
#   'end_pos': 9,
#   'entities': [['GO:0034005',
#     0.6519118198573883,
#     'reaction -(r)-germacrene farnesyl germacrene forming -(10r)-germacrene = gas catalysis synthase -germacrene diphosphate activity trans 2 + trans,6 lyase'],
#    ['PATO:0001737',
#     0.651926041267722,
#     'configuration having quality arrangement virtue parts characteristics exhibits gas inhering gaseus physical gases bearer']],
#   'best_entity': ('PATO:0001737', 0.651926041267722)},
#  {'text': 'linear',
#   'end_pos': 28,
#   'start_pos': 22,
#   'entities': [['PATO:0001199',
#     1.1909946650489613,
#     'opposite quality narrow virtue inhering margins linear parallel shape bearer']],
#   'best_entity': ('PATO:0001199', 1.1909946650489613)},
#  {'text': 'structure',
#   'end_pos': 48,
#   'start_pos': 39,
#   'entities': [['PATO:0000141',
#     1.01956804705477,
#     'structure morphology quality form arrangements connectivity virtue relative relational position organism parts inhering pattern conformation structural shape underlying bearer'],
#    ['SIO:000600', 0.7283343892883456, 'structure']],
#   'best_entity': ('PATO:0000141', 1.01956804705477)},
#  {'text': 'liquid',
#   'end_pos': 66,
#   'start_pos': 60,
#   'entities': [['PATO:0001735', 1.3852977946039937, 'configuration liquid']],
#   'best_entity': ('PATO:0001735', 1.3852977946039937)},
#  {'text': 'state',
#   'end_pos': 72,
#   'start_pos': 67,
#   'entities': [['SIO:000662', 1.3853053506810487, 'state']],
#   'best_entity': ('SIO:000662', 1.3853053506810487)},
#  {'start_pos': 75,
#   'text': 'fluctuating',
#   'end_pos': 86,
#   'entities': [['PATO:0002374',
#     1.3852826828001976,
#     'fluctuating alteration cyclic recurrent']],
#   'best_entity': ('PATO:0002374', 1.3852826828001976)},
#  {'text': 'structure',
#   'start_pos': 99,
#   'end_pos': 108,
#   'entities': [['PATO:0000141',
#     1.01956804705477,
#     'structure morphology quality form arrangements connectivity virtue relative relational position organism parts inhering pattern conformation structural shape underlying bearer'],
#    ['SIO:000600', 0.7283343892883456, 'structure']],
#   'best_entity': ('PATO:0000141', 1.01956804705477)}]

# %%
text = 'In protein crystallography it is used as a mimic of phosphate.'
mentions = e_linker.link_entities(text)
_print_colorful_text(text, mentions)
mentions
# Out:
# In protein crystallography it is used as a mimic of phosphate.
# [{'end_pos': 10,
#   'start_pos': 3,
#   'text': 'protein',
#   'entities': [['CHEBI:16541',
#     0.24210837578107897,
#     'chains synthesized occurring naturally protein chain ribosome polypeptide'],
#    ['CHEBI:36080',
#     14.405333126219205,
#     'biological synthesized proteins protein macromolecule consisting chain minimally ribosome polypeptide'],
#    ['PR:000000001', 93.33539210040469, 'protein'],
#    ['SIO:010043', 0.24211515460545963, 'protein']],
#   'best_entity': ('PR:000000001', 93.33539210040469)},
#  {'text': 'phosphate',
#   'start_pos': 52,
#   'end_pos': 61,
#   'entities': [['CHEBI:35780',
#     0.4541001912081851,
#     'oxoanion base conjugate phosphorus ion pi phosphoric phosphate ions acid'],
#    ['CHEBI:18367',
#     0.25948374789757,
#     'hydrogenphosphate base conjugate tetraoxidophosphate(3- po4](3- tetraoxophosphate(v orthophosphate ion phosphate(3- po4(3- tetraoxophosphate(3- phosphate'],
#    ['CHEBI:43474',
#     0.12973979838598487,
#     'hydrogenphosphate base hydrogentetraoxophosphate(v po3(oh)](2- hydrogen(tetraoxidophosphate)(2- dihydrogenphosphate hydrogentetraoxophosphate(2- hpo4(2- inorganic p(oh)o3](2- group conjugate hydroxidotrioxidophosphate(2- ion hydrogen phosphate'],
#    ['CHEBI:26020',
#     90.94650749489375,
#     'anionic analogues entities coordination describe salts chemistry phosphates esters inorganic term acids atom central phosphorus chalcogen phosphoric phosphate oligophosphoric'],
#    ['CHEBI:26078',
#     0.1297346099873775,
#     'phosphorsaeure oxo phosphorique phosphoricum tetraoxophosphate(3- acidum oxoacid trihydrogen acide po(oh)3 orthophosphoric tetraoxophosphoric covalently groups acid hydroxy phosphorsaeureloesungen trihydroxidooxidophosphorus atom joined central phosphorus phosphoric phosphate h3po4 consists']],
#   'best_entity': ('CHEBI:26020', 90.94650749489375)}]

# %%
text = """The process in which an antigen-presenting cell expresses peptide antigen in 
association with an MHC protein complex on its cell surface, including proteolysis and 
transport steps for the peptide antigen both prior to and following assembly with the MHC protein complex.
 The peptide antigen is typically, but not always, processed from an endogenous or exogenous protein."""

mentions = e_linker.link_entities(text)
_print_colorful_text(text, mentions)
mentions
# Out:
# The process in which an antigen-presenting cell expresses peptide antigen in
# association with an MHC protein complex on its cell surface, including proteolysis and
# transport steps for the peptide antigen both prior to and following assembly with the MHC protein complex.
#  The peptide antigen is typically, but not always, processed from an endogenous or exogenous protein.
# [{'text': 'process',
#   'end_pos': 11,
#   'start_pos': 4,
#   'entities': [['BFO:0000015',
#     0.9871253304300318,
#     'depends_on p t. material t occurrent parts proper temporal entity time s process'],
#    ['UBERON:0004529',
#     0.06873829428303153,
#     'larger papilla processes anatomical lamella organ spine shelf flanges outgrowth processus flange body lamellae lamina tissue shelves ridges protrusion process projection projections ridge laminae'],
#    ['ProcessualEntity', 0.03299741649915768, 'process'],
#    ['SIO:000006', 0.3657213661989977, 'process'],
#    ['ZFA:0001637',
#     0.013748483604798002,
#     'bone process extension tissue bony portion connective projection projections']],
#   'best_entity': ('BFO:0000015', 0.9871253304300318)},
#  {'end_pos': 31,
#   'text': 'antigen',
#   'start_pos': 24,
#   'entities': [['CHEBI:59132',
#     1.0132795614515877,
#     'cell response antigen receptor histocompability antigens complex mhc antibody t stimulates presentation substance production major binding body immune'],
#    ['SIO:010419', 0.17999388631617397, 'antigen']],
#   'best_entity': ('CHEBI:59132', 1.0132795614515877)},
#  {'end_pos': 47,
#   'start_pos': 43,
#   'text': 'cell',
#   'entities': [['CL:0000000', 0.9963794008112181, 'cell'],
#    ['GO:0005623', 0.4906309601235929, 'cell'],
#    ['SIO:010001', 0.004122949244736076, 'cell'],
#    ['ZFA:0009000',
#     0.5208450882814305,
#     'cell anatomical maximally structure plasma cells surrounded parts membrane connected compartment']],
#   'best_entity': ('CL:0000000', 0.9963794008112181)},
#  {'end_pos': 65,
#   'start_pos': 58,
#   'text': 'peptide',
#   'entities': [['CHEBI:16670',
#     0.999601251494474,
#     'formed different x nitrogen structures loss includes nh2 derived carbonyl peptide oh peptido formation covalent amino = peptides carbon alpha bond applied peptidos peptid formal term nhr usually molecules acid acids atom etc amide carboxylic water'],
#    ['PR:000018263', 0.07035682353561312, 'acid amino chain'],
#    ['PR:000018264', 0.00039196001969700906, 'proteolytic product cleavage'],
#    ['SIO:001425', 9.800423287708589e-05, 'peptide']],
#   'best_entity': ('CHEBI:16670', 0.999601251494474)},
#  {'text': 'antigen',
#   'end_pos': 73,
#   'start_pos': 66,
#   'entities': [['CHEBI:59132',
#     1.0132795614515877,
#     'cell response antigen receptor histocompability antigens complex mhc antibody t stimulates presentation substance production major binding body immune'],
#    ['SIO:010419', 0.17999388631617397, 'antigen']],
#   'best_entity': ('CHEBI:59132', 1.0132795614515877)},
#  {'text': 'association',
#   'end_pos': 89,
#   'start_pos': 78,
#   'entities': [['SIO:000897', 1.0441865110773394, 'association']],
#   'best_entity': ('SIO:000897', 1.0441865110773394)},
#  {'start_pos': 102,
#   'text': 'protein',
#   'end_pos': 109,
#   'entities': [['CHEBI:16541',
#     0.19253101205984427,
#     'chains synthesized occurring naturally protein chain ribosome polypeptide'],
#    ['CHEBI:36080',
#     11.455503581412783,
#     'biological synthesized proteins protein macromolecule consisting chain minimally ribosome polypeptide'],
#    ['PR:000000001', 74.22278326439324, 'protein'],
#    ['SIO:010043', 0.19253640276107198, 'protein']],
#   'best_entity': ('PR:000000001', 74.22278326439324)},
#  {'text': 'complex',
#   'end_pos': 117,
#   'start_pos': 110,
#   'entities': [['PATO:0001504',
#     1.1238313876578825,
#     'compounded inhering virtue intricate complex quality complexity bearer']],
#   'best_entity': ('PATO:0001504', 1.1238313876578825)},
#  {'start_pos': 125,
#   'end_pos': 129,
#   'text': 'cell',
#   'entities': [['CL:0000000', 0.9963794008112181, 'cell'],
#    ['GO:0005623', 0.4906309601235929, 'cell'],
#    ['SIO:010001', 0.004122949244736076, 'cell'],
#    ['ZFA:0009000',
#     0.5208450882814305,
#     'cell anatomical maximally structure plasma cells surrounded parts membrane connected compartment']],
#   'best_entity': ('CL:0000000', 0.9963794008112181)},
#  {'text': 'surface',
#   'start_pos': 130,
#   'end_pos': 137,
#   'entities': [['UBERON:0002416',
#     0.8998650573579017,
#     'barrier integumentum integumental covering glands surface animal connected include plus adnexa environment epidermis anatomical organism dermis commune hair integumentary vertebrates dermal cuticle body forms scales associated system invertebrates external consists'],
#    ['BSPO:0000005', 2.339892443934418, '2d continuant anatomical surface']],
#   'best_entity': ('BSPO:0000005', 2.339892443934418)},
#  {'text': 'proteolysis',
#   'start_pos': 149,
#   'end_pos': 160,
#   'entities': [['GO:0006508',
#     1.0117705322575425,
#     'cleavage dependent peptide proteolysis amino bonds atp peptidolysis acids polypeptides smaller and/or hydrolysis proteins']],
#   'best_entity': ('GO:0006508', 1.0117705322575425)},
#  {'start_pos': 166,
#   'text': 'transport',
#   'end_pos': 175,
#   'entities': [['GO:0006810',
#     1.0710867502466221,
#     'cell single cells agent directed macromolecules multicellular pore complexes organelles motor solute components organism transport protein transporter movement ions molecule molecules substances cellular means small exchange']],
#   'best_entity': ('GO:0006810', 1.0710867502466221)},
#  {'end_pos': 197,
#   'text': 'peptide',
#   'start_pos': 190,
#   'entities': [['CHEBI:16670',
#     0.999601251494474,
#     'formed different x nitrogen structures loss includes nh2 derived carbonyl peptide oh peptido formation covalent amino = peptides carbon alpha bond applied peptidos peptid formal term nhr usually molecules acid acids atom etc amide carboxylic water'],
#    ['PR:000018263', 0.07035682353561312, 'acid amino chain'],
#    ['PR:000018264', 0.00039196001969700906, 'proteolytic product cleavage'],
#    ['SIO:001425', 9.800423287708589e-05, 'peptide']],
#   'best_entity': ('CHEBI:16670', 0.999601251494474)},
#  {'end_pos': 205,
#   'text': 'antigen',
#   'start_pos': 198,
#   'entities': [['CHEBI:59132',
#     1.0132795614515877,
#     'cell response antigen receptor histocompability antigens complex mhc antibody t stimulates presentation substance production major binding body immune'],
#    ['SIO:010419', 0.17999388631617397, 'antigen']],
#   'best_entity': ('CHEBI:59132', 1.0132795614515877)},
#  {'end_pos': 263,
#   'start_pos': 256,
#   'text': 'protein',
#   'entities': [['CHEBI:16541',
#     0.19253101205984427,
#     'chains synthesized occurring naturally protein chain ribosome polypeptide'],
#    ['CHEBI:36080',
#     11.455503581412783,
#     'biological synthesized proteins protein macromolecule consisting chain minimally ribosome polypeptide'],
#    ['PR:000000001', 74.22278326439324, 'protein'],
#    ['SIO:010043', 0.19253640276107198, 'protein']],
#   'best_entity': ('PR:000000001', 74.22278326439324)},
#  {'start_pos': 264,
#   'text': 'complex',
#   'end_pos': 271,
#   'entities': [['PATO:0001504',
#     1.1238313876578825,
#     'compounded inhering virtue intricate complex quality complexity bearer']],
#   'best_entity': ('PATO:0001504', 1.1238313876578825)},
#  {'start_pos': 277,
#   'end_pos': 292,
#   'text': 'peptide antigen',
#   'entities': [['CHEBI:166824',
#     1.0800078134089486,
#     '12 16 antigen histocompatibility cells mhc peptide bind 8 10 peptides residue antigenic ii major optimal displayed class molecules residues size accommodate 30 presenting 13']],
#   'best_entity': ('CHEBI:166824', 1.0800078134089486)},
#  {'start_pos': 366,
#   'end_pos': 373,
#   'text': 'protein',
#   'entities': [['CHEBI:16541',
#     0.19253101205984427,
#     'chains synthesized occurring naturally protein chain ribosome polypeptide'],
#    ['CHEBI:36080',
#     11.455503581412783,
#     'biological synthesized proteins protein macromolecule consisting chain minimally ribosome polypeptide'],
#    ['PR:000000001', 74.22278326439324, 'protein'],
#    ['SIO:010043', 0.19253640276107198, 'protein']],
#   'best_entity': ('PR:000000001', 74.22278326439324)}]

# %%
text = 'A tiger is a carnovire of the mammal family.'
mentions = e_linker.link_entities(text)
_print_colorful_text(text, mentions)
mentions
# Out:
# A tiger is a carnovire of the mammal family.
# [{'text': 'tiger',
#   'start_pos': 2,
#   'end_pos': 7,
#   'entities': [['NCBITaxon:9694',
#     1.4001970292471355,
#     'panthera tiger tigris']],
#   'best_entity': ('NCBITaxon:9694', 1.4001970292471355)},
#  {'start_pos': 30,
#   'text': 'mammal',
#   'end_pos': 36,
#   'entities': [['NCBITaxon:40674', 0.9999940000479997, 'mammalia']],
#   'best_entity': ('NCBITaxon:40674', 0.9999940000479997)},
#  {'end_pos': 43,
#   'start_pos': 37,
#   'text': 'family',
#   'entities': [['NCBITaxon:family', 0.5540460053084098, 'family'],
#    ['SIO:001063', 0.5540460053084098, 'family'],
#    ['STATO:0000257',
#     1.1080122364480558,
#     'common linked ancestor number demonstrated group stipulated groups descent adoption family domestic marriage']],
#   'best_entity': ('STATO:0000257', 1.1080122364480558)}]

# %%
text = """Natural gas consists primarily of methane that is clean, non-toxic, and has abundant natural reserves. 
However, methane is also a greenhouse gas whose greenhouse effect is more than 20 times than that of carbon dioxide. 
The conversion of methane into other value-added chemicals has been an important research area in the field of catalysis for many years. 
One of the most challenging processes of high industrial importance is the conversion of methane to methanol (CHEBI:17790), 
a simple alcohol that is liquid under ambient conditions and can be easily stored and transported compared to methane [1]. 
Methanol is used as an important chemical raw material to make products such as paints and plastics and as an additive to gasoline [2]."""

mentions = e_linker.link_entities(text)
_print_colorful_text(text, mentions)
mentions
# Out:
# Natural gas consists primarily of methane that is clean, non-toxic, and has abundant natural reserves.
# However, methane is also a greenhouse gas whose greenhouse effect is more than 20 times than that of carbon dioxide.
# The conversion of methane into other value-added chemicals has been an important research area in the field of catalysis for many years.
# One of the most challenging processes of high industrial importance is the conversion of methane to methanol (CHEBI:17790),
# a simple alcohol that is liquid under ambient conditions and can be easily stored and transported compared to methane [1].
# Methanol is used as an important chemical raw material to make products such as paints and plastics and as an additive to gasoline [2].
# [{'start_pos': 8,
#   'text': 'gas',
#   'end_pos': 11,
#   'entities': [['GO:0034005',
#     0.5257933837775433,
#     'reaction -(r)-germacrene farnesyl germacrene forming -(10r)-germacrene = gas catalysis synthase -germacrene diphosphate activity trans 2 + trans,6 lyase'],
#    ['PATO:0001737',
#     0.5257973719319609,
#     'configuration having quality arrangement virtue parts characteristics exhibits gas inhering gaseus physical gases bearer']],
#   'best_entity': ('PATO:0001737', 0.5257973719319609)},
#  {'start_pos': 34,
#   'text': 'methane',
#   'end_pos': 41,
#   'entities': [['CHEBI:16183',
#     1.170687657091637,
#     'metano single ch4 methan odourless non toxic flammable marsh atoms colourless b.p bonds gas attached carbon methane -161degreec methyl compound tetrahydridocarbon hydrogen hydride']],
#   'best_entity': ('CHEBI:16183', 1.170687657091637)},
#  {'text': 'toxic',
#   'end_pos': 66,
#   'start_pos': 61,
#   'entities': [['SIO:001009', 1.0637619798059499, 'toxic']],
#   'best_entity': ('SIO:001009', 1.0637619798059499)},
#  {'start_pos': 113,
#   'text': 'methane',
#   'end_pos': 120,
#   'entities': [['CHEBI:16183',
#     1.170687657091637,
#     'metano single ch4 methan odourless non toxic flammable marsh atoms colourless b.p bonds gas attached carbon methane -161degreec methyl compound tetrahydridocarbon hydrogen hydride']],
#   'best_entity': ('CHEBI:16183', 1.170687657091637)},
#  {'start_pos': 142,
#   'text': 'gas',
#   'end_pos': 145,
#   'entities': [['GO:0034005',
#     0.5257933837775433,
#     'reaction -(r)-germacrene farnesyl germacrene forming -(10r)-germacrene = gas catalysis synthase -germacrene diphosphate activity trans 2 + trans,6 lyase'],
#    ['PATO:0001737',
#     0.5257973719319609,
#     'configuration having quality arrangement virtue parts characteristics exhibits gas inhering gaseus physical gases bearer']],
#   'best_entity': ('PATO:0001737', 0.5257973719319609)},
#  {'end_pos': 211,
#   'start_pos': 205,
#   'text': 'carbon',
#   'entities': [['CHEBI:33415', 0.7948317742483895, 'elemental carbon'],
#    ['CHEBI:27594',
#     0.3222254311275488,
#     'carbono atom 6c kohlenstoff c carbone carbonium carbon']],
#   'best_entity': ('CHEBI:33415', 0.7948317742483895)},
#  {'end_pos': 247,
#   'text': 'methane',
#   'start_pos': 240,
#   'entities': [['CHEBI:16183',
#     1.170687657091637,
#     'metano single ch4 methan odourless non toxic flammable marsh atoms colourless b.p bonds gas attached carbon methane -161degreec methyl compound tetrahydridocarbon hydrogen hydride']],
#   'best_entity': ('CHEBI:16183', 1.170687657091637)},
#  {'start_pos': 312,
#   'text': 'area',
#   'end_pos': 316,
#   'entities': [['EFO:0001696',
#     0.26001401027468735,
#     'describes extent dimensional area entity material quality size'],
#    ['PATO:0001323',
#     1.3000675859352395,
#     'inhering extent virtue 2 dimensional area d quality bearer'],
#    ['SIO:000045', 0.5200349241048152, 'area']],
#   'best_entity': ('PATO:0001323', 1.3000675859352395)},
#  {'end_pos': 329,
#   'start_pos': 324,
#   'text': 'field',
#   'entities': [['UBERON:0007688',
#     1.0209613891255085,
#     'cells contiguous typically correspond arranged later indistinct populations anlagen plane developmental organ extent anlage morphologically tissue field future']],
#   'best_entity': ('UBERON:0007688', 1.0209613891255085)},
#  {'start_pos': 388,
#   'end_pos': 397,
#   'text': 'processes',
#   'entities': [['UBERON:0004529',
#     1.0151800973074487,
#     'larger papilla processes anatomical lamella organ spine shelf flanges outgrowth processus flange body lamellae lamina tissue shelves ridges protrusion process projection projections ridge laminae']],
#   'best_entity': ('UBERON:0004529', 1.0151800973074487)},
#  {'end_pos': 456,
#   'text': 'methane',
#   'start_pos': 449,
#   'entities': [['CHEBI:16183',
#     1.170687657091637,
#     'metano single ch4 methan odourless non toxic flammable marsh atoms colourless b.p bonds gas attached carbon methane -161degreec methyl compound tetrahydridocarbon hydrogen hydride']],
#   'best_entity': ('CHEBI:16183', 1.170687657091637)},
#  {'end_pos': 468,
#   'text': 'methanol',
#   'start_pos': 460,
#   'entities': [['CHEBI:17790',
#     1.025122034549252,
#     'simplest aliphatic methylalkohol wood ch3oh meoh methanol primary spirit comprising carbinol alcohol group methyl naphtha']],
#   'best_entity': ('CHEBI:17790', 1.025122034549252)},
#  {'end_pos': 493,
#   'start_pos': 487,
#   'text': 'simple',
#   'entities': [['PATO:0001503',
#     1.0516047147836667,
#     'compound virtue complicated parts simple quality having complexity bearer']],
#   'best_entity': ('PATO:0001503', 1.0516047147836667)},
#  {'text': 'alcohol',
#   'end_pos': 501,
#   'start_pos': 494,
#   'entities': [['CHEBI:30879',
#     1.0092849943379056,
#     'hydroxy compound atom alcohol -oh saturated group attached alcohols carbon'],
#    ['CHEBI:16236',
#     0.000496995191763823,
#     '200 1 ethylol diluted sd-13a oeth 70 pdd pure 95 spirit alcare cd-10 alcohol 9020 colamine c2h5oh sd-3a spiritus aminoethyl usaf sd-28 c1 synasol 40 inchikey sd-23a hydroxyethane algrain 20 aminoethanol etoh alkohol hydroxyethylamine cco c degermer anhydrous 3 cd-5 50 formula m-50 hydroxide glycinol ethanolamine caswell reagent hydrate ethylolamine sd-17 proof alcool inchi=1 h3h,2h2,1h3 jaysol 30 cd-5a aethanol etilico pyro absolute 5 etanolo tecsol ethanol 80 thanol = 10 ek-1597 silent anhydrol 531 bp beta uhfffaoyab conditioner 426 2 etanol 96 aethylalkohol sd-39b vini lfqscwfljhtthz sd-39c water ethylique sd-1 envision methylcarbinol c2h6o thiofaco hand dehydrated eta denatured ethyl extra s hsdb ch2me(oh']],
#   'best_entity': ('CHEBI:30879', 1.0092849943379056)},
#  {'text': 'liquid',
#   'end_pos': 516,
#   'start_pos': 510,
#   'entities': [['PATO:0001735', 1.0637599623585083, 'configuration liquid']],
#   'best_entity': ('PATO:0001735', 1.0637599623585083)},
#  {'end_pos': 602,
#   'text': 'methane',
#   'start_pos': 595,
#   'entities': [['CHEBI:16183',
#     1.170687657091637,
#     'metano single ch4 methan odourless non toxic flammable marsh atoms colourless b.p bonds gas attached carbon methane -161degreec methyl compound tetrahydridocarbon hydrogen hydride']],
#   'best_entity': ('CHEBI:16183', 1.170687657091637)}]

# %%
text = "Altered gut microbiome composition in HIV infection: causes, effects and potential intervention."
mentions = e_linker.link_entities(text)
_print_colorful_text(text, mentions)
print(mentions)
# Out:
# Altered gut microbiome composition in HIV infection: causes, effects and potential intervention.
#
# [{'end_pos': 11, 'start_pos': 8, 'text': 'gut', 'entities': [['UBERON:0001007', 0.4048229062718224, 'organs gastrointestinal tract devoted food residual digestion anatomical parts ingestion discharge assimilation digestive alimentary gut wastes system'], ['UBERON:0001555', 0.3238696587271261, 'anus tract digestive mouth alimentary canal enteric extending gut tube'], ['UBERON:0004907', 0.161933210201473, 'gi gastrointestinal tract intestines definition region digestive lower beginning extending gut anus[go'], ['MA:0000917', 0.08097105809703307, 'gut'], ['ZFA:0000112', 0.16193563896282193, 'organs tract associated alimentary digestive canal enteric gut tube']], 'best_entity': ('UBERON:0001007', 0.4048229062718224)}, {'text': 'microbiome', 'start_pos': 12, 'end_pos': 22, 'entities': [['EFO:0004982', 1.338994983561869, 'microbiome microorganisms collectivity collection']], 'best_entity': ('EFO:0004982', 1.338994983561869)}, {'text': 'composition', 'start_pos': 23, 'end_pos': 34, 'entities': [['PATO:0000025', 1.0624914572311293, 'single structure quantities composed composition virtue relative ratios content inhering entity physical compositionality subparts bearer']], 'best_entity': ('PATO:0000025', 1.0624914572311293)}, {'text': 'infection', 'start_pos': 42, 'end_pos': 51, 'entities': [['EFO:0000544', 0.8594911588763062, 'infection'], ['EFO:0005741', 273.7219320136237, 'indirect direct diseases viral presence agent infectious disorder manifestations clinical parasitic resulting activity microbial transmitted disease communicable contact transmissible infection']], 'best_entity': ('EFO:0005741', 273.7219320136237)}, {'end_pos': 95, 'start_pos': 83, 'text': 'intervention', 'entities': [['EFO:0002571', 1.0602045520937382, 'procedures preventive interventional encompasses patient intended behavioral interventiondescription procedure environmental surgical produces course acts intervention strategies general term activity population palliative medical therapeutic alter effects effect disease social']], 'best_entity': ('EFO:0002571', 1.0602045520937382)}]

# %%
text = "Batman advices to follow your gut when you eat food"
mentions = e_linker.link_entities(text)
_print_colorful_text(text, mentions)
print(mentions)
# Out:
# Batman advices to follow your gut when you eat food
#
# [{'end_pos': 33, 'start_pos': 30, 'text': 'gut', 'entities': [['UBERON:0001007', 0.7159732384208091, 'organs gastrointestinal tract devoted food residual digestion anatomical parts ingestion discharge assimilation digestive alimentary gut wastes system'], ['UBERON:0001555', 0.3521147213636813, 'anus tract digestive mouth alimentary canal enteric extending gut tube'], ['UBERON:0004907', 0.17605618709910878, 'gi gastrointestinal tract intestines definition region digestive lower beginning extending gut anus[go'], ['MA:0000917', 0.08803132109570196, 'gut'], ['ZFA:0000112', 0.17605794748494133, 'organs tract associated alimentary digestive canal enteric gut tube']], 'best_entity': ('UBERON:0001007', 0.7159732384208091)}, {'text': 'food', 'start_pos': 47, 'end_pos': 51, 'entities': [['CHEBI:33290', 1.6267142776939445, 'food']], 'best_entity': ('CHEBI:33290', 1.6267142776939445)}]

# %%
text = """
Coronavirus disease (COVID-19) first presented in Wuhan, Hubei province, China in December 2019. Since then, it has rapidly spread across the world, and is now formally considered a pandemic. The disease does not discriminate but increasing age and the presence of comorbidities are associated with severe form of the disease and poor outcomes. Although the prevalence of COVID-19 in patients with cardiovascular disease is under-reported, there is evidence that pre-existing cardiac disease can render individuals vulnerable. It is thought that COVID-19 may have both a direct and indirect effect on the cardiovascular system; however, the primary mechanism of underlying cardiovascular involvement is still uncertain. Of particular interest is the role of angiotensin-converting enzyme 2, which is well known for its cardiovascular effects and is also considered to be important in the pathogenesis of COVID-19. With a range of different drug candidates being suggested, effective anti-virals and vaccines are an area of on-going research. While our knowledge of COVID-19 continues to rapidly expand, this review highlights recent advances in our understanding of the interaction between COVID-19 and the cardiovascular system. 
"""
mentions = e_linker.link_entities(text)
_print_colorful_text(text, mentions)
print(mentions)
# Out:
# 2021-12-14 16:51:51,608 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2021-12-14 16:51:51,609 Ignore 1 sentence(s) with no tokens.
#
#
# Coronavirus disease (COVID-19) first presented in Wuhan, Hubei province, China in December 2019. Since then, it has rapidly spread across the world, and is now formally considered a pandemic. The disease does not discriminate but increasing age and the presence of comorbidities are associated with severe form of the disease and poor outcomes. Although the prevalence of COVID-19 in patients with cardiovascular disease is under-reported, there is evidence that pre-existing cardiac disease can render individuals vulnerable. It is thought that COVID-19 may have both a direct and indirect effect on the cardiovascular system; however, the primary mechanism of underlying cardiovascular involvement is still uncertain. Of particular interest is the role of angiotensin-converting enzyme 2, which is well known for its cardiovascular effects and is also considered to be important in the pathogenesis of COVID-19. With a range of different drug candidates being suggested, effective anti-virals and vaccines are an area of on-going research. While our knowledge of COVID-19 continues to rapidly expand, this review highlights recent advances in our understanding of the interaction between COVID-19 and the cardiovascular system.
#
#
# [{'text': 'disease', 'start_pos': 12, 'end_pos': 19, 'entities': [['EFO:0000408', 0.9996415009564189, 'disease'], ['DOID:4', 0.011105604385882584, 'disease'], ['OGMS:0000031', 0.00013710370564162588, 'disorders processes disposition pathological organism exists ii disease undergo'], ['SIO:010299', 0.00013710622698620475, 'disease']], 'best_entity': ('EFO:0000408', 0.9996415009564189)}, {'end_pos': 72, 'start_pos': 64, 'text': 'province', 'entities': [['SIO:000661', 1.0420675210027326, 'province']], 'best_entity': ('SIO:000661', 1.0420675210027326)}, {'text': 'disease', 'end_pos': 203, 'start_pos': 196, 'entities': [['EFO:0000408', 0.9996415009564189, 'disease'], ['DOID:4', 0.011105604385882584, 'disease'], ['OGMS:0000031', 0.00013710370564162588, 'disorders processes disposition pathological organism exists ii disease undergo'], ['SIO:010299', 0.00013710622698620475, 'disease']], 'best_entity': ('EFO:0000408', 0.9996415009564189)}, {'start_pos': 214, 'text': 'discriminate', 'end_pos': 226, 'entities': [['PATO:0001319', 1.0420483576769477, 'discriminate quality virtue capable stimuli perceiving discrimination differences bearer']], 'best_entity': ('PATO:0001319', 1.0420483576769477)}, {'start_pos': 242, 'text': 'age', 'end_pos': 245, 'entities': [['CHEBI:84123', 0.17038390741594273, 'cells non result end enzymatic premature carbohydrate age glycation resulting prone advanced product stiffer damage products aging ages derivatives proteins glycosylation'], ['PATO:0000011', 0.5111669960599707, 'inhering existed virtue age long time quality bearer'], ['EFO:0000246', 2.3853801863255963, 'cycle days elapsed 3 age organism planting beginning post developmental temporal specified time measurement life identifiable period e.g. point stage'], ['SIO:001013', 0.17039174047727074, 'age']], 'best_entity': ('EFO:0000246', 2.3853801863255963)}, {'text': 'presence', 'end_pos': 262, 'start_pos': 254, 'entities': [['PATO:0000070', 1.0139303160869095, 'quantitative type presence number organism count absence entities']], 'best_entity': ('PATO:0000070', 1.0139303160869095)}, {'end_pos': 294, 'start_pos': 284, 'text': 'associated', 'entities': [['PATO:0001668', 1.0340994565720676, 'quality close virtue interacting inhering physically entity proximity structural associated bearer']], 'best_entity': ('PATO:0001668', 1.0340994565720676)}, {'text': 'severe', 'start_pos': 300, 'end_pos': 306, 'entities': [['SIO:001215', 1.0420675210027326, 'severe']], 'best_entity': ('SIO:001215', 1.0420675210027326)}, {'text': 'disease', 'end_pos': 326, 'start_pos': 319, 'entities': [['EFO:0000408', 0.9996415009564189, 'disease'], ['DOID:4', 0.011105604385882584, 'disease'], ['OGMS:0000031', 0.00013710370564162588, 'disorders processes disposition pathological organism exists ii disease undergo'], ['SIO:010299', 0.00013710622698620475, 'disease']], 'best_entity': ('EFO:0000408', 0.9996415009564189)}, {'start_pos': 359, 'end_pos': 369, 'text': 'prevalence', 'entities': [['STATO:0000412', 1.0421010031231894, 'prevalence formed total diagnosed number disease divided population subjects ratio size']], 'best_entity': ('STATO:0000412', 1.0421010031231894)}, {'text': 'disease', 'end_pos': 421, 'start_pos': 414, 'entities': [['EFO:0000408', 0.9996415009564189, 'disease'], ['DOID:4', 0.011105604385882584, 'disease'], ['OGMS:0000031', 0.00013710370564162588, 'disorders processes disposition pathological organism exists ii disease undergo'], ['SIO:010299', 0.00013710622698620475, 'disease']], 'best_entity': ('EFO:0000408', 0.9996415009564189)}, {'start_pos': 450, 'text': 'evidence', 'end_pos': 458, 'entities': [['SIO:001394', 1.0420675210027326, 'evidence']], 'best_entity': ('SIO:001394', 1.0420675210027326)}, {'text': 'pre', 'end_pos': 467, 'start_pos': 464, 'entities': [['UBERON:0001782', 0.4096518185619645, 'pigment cell pre covering rpe monolayer outside cells develops retinal retina epithelium nourishes overlying layers optic p. attached pigmented firmly pigmentosum retinae l ...

# %%
docs = ["Zika virus (ZIKV) is an arthropod-borne virus (arbovirus) in the genus Flavivirus and the family Flaviviridae. ZIKV was first isolated from a nonhuman primate in 1947 and from mosquitoes in 1948 in Africa, and ZIKV infections in humans were sporadic for half a century before emerging in the Pacific and the Americas. ZIKV is usually transmitted by the bite of infected mosquitoes. The clinical presentation of Zika fever is nonspecific and can be misdiagnosed as other infectious diseases, especially those due to arboviruses such as dengue and chikungunya. ZIKV infection was associated with only mild illness prior to the large French Polynesian outbreak in 2013 and 2014, when severe neurological complications were reported, and the emergence in Brazil of a dramatic increase in severe congenital malformations (microcephaly) suspected to be associated with ZIKV. Laboratory diagnosis of Zika fever relies on virus isolation or detection of ZIKV-specific RNA. Serological diagnosis is complicated by cross-reactivity among members of the Flavivirus genus. The adaptation of ZIKV to an urban cycle involving humans and domestic mosquito vectors in tropical areas where dengue is endemic suggests that the incidence of ZIKV infections may be underestimated. There is a high potential for ZIKV emergence in urban centers in the tropics that are infested with competent mosquito vectors such as Aedes aegypti and Aedes albopictus. ",
 "Zika virus is a mosquitoborne flavivirus that is the focus of an ongoing pandemic and public health emergency. Previously limited to sporadic cases in Africa and Asia, the emergence of Zika virus in Brazil in 2015 heralded rapid spread throughout the Americas. Although most Zika virus infections are characterized by subclinical or mild influenza-like illness, severe manifestations have been described, including Guillain-Barre syndrome in adults and microcephaly in babies born to infected mothers. Neither an effective treatment nor a vaccine is available for Zika virus; therefore, the public health response primarily focuses on preventing infection, particularly in pregnant women. Despite growing knowledge about this virus, questions remain regarding the virus's vectors and reservoirs, pathogenesis, genetic diversity, and potential synergistic effects of co-infection with other circulating viruses. These questions highlight the need for research to optimize surveillance, patient management, and public health intervention in the current Zika virus epidemic. ",
 "The emergence of Zika virus (ZIKV) as a major public health threat has focused research on understanding virus biology and developing a suite of strategies for disease intervention. Recent advances in cryoelectron microscopy have accelerated structure-function studies of flaviviruses and of ZIKV in particular. Structures of the mature and immature ZIKV have demonstrated its similarity with other known flaviviruses such as dengue and West Nile viruses. However, ZIKV's unique pathobiology demands an explanation of how its structure, although similar to its flavivirus relatives, is sufficiently unique to address questions of receptor specificity, transmission, and antigenicity. Progress in defining the immunodominant epitopes and how neutralizing antibodies bind to them will provide great insight as vaccines progress through clinical trials. Identification of host receptors will substantially illuminate the interesting ZIKV tropism and provide insights into pathogenesis. Although the answers to all of these questions are not yet available, rapid progress in combining structural biology with other techniques is revealing the similarities and the differences in virion structure and function between ZIKV and related flaviviruses. ",
 "AIDS is a syndrome that represents the most severe form of infection with the retrovirus HIV. Opportunistic infections, uncommon malignant neoplasms, and intractable immunologic deficiency are hallmarks of AIDS. To date, the syndrome in the U.S. is seen mainly in epidemiologically restricted populations. It appears to be transmitted in a manner analogous to hepatitis B. There is no available means of reversing the immune deficit. Therapy is restricted to treating the complicating infections and tumors. Those having been diagnosed with P. carinii pneumonia may benefit from therapy with AZT. The spread of HIV and the syndrome can only be reduced by preventive measures until an effective and safe vaccine can be developed. ",
 "Women are the fastest growing segment of people with acquired immunodeficiency syndrome (AIDS), yet they often receive this diagnosis when the disease is in its advanced stages. New therapies have caused human immunodeficiency virus (HIV) to become a chronic and treatable disease for many of those afflicted. Primary care providers must be cognizant of the initial symptoms to facilitate early diagnosis and prompt treatment for women with HIV. Early signs of HIV in women are subtle. Providers must consider a diagnosis of HIV in women who present with vaginal infections, abnormal pap smears, or sexually transmitted diseases that are unusually severe, recurrent, and resistant to treatment efforts. These signs and symptoms, along with a corroborating history, may be early clues to HIV. Primary care providers, in conjunction with HIV specialists, must strive to decrease the incidence, morbidity, and mortality of the disease in women."
 "1. Acquired immunodeficiency syndrome (AIDS) in the elderly accounts for 10% of all AIDS cases; although blood transfusion is thought to be the most likely mode of transmission in the elderly, AIDS acquired through sexual contact should not be overlooked. 2. Diagnosing AIDS in the elderly is a major problem; perhaps the biggest problem in diagnosing AIDS in elders is that many clinicians fail to recognize AIDS as a possibility. 3. The nursing implications concerning AIDS in the elderly are endless. Practitioners, educators, and researchers can have a major impact in combating this problem. ",
 " Another aspect of AIDS epidemic is the public reaction or treatment of the disease and its victims and the potential for discriminatory actions. The issues of discrimination and treatment are compounded by the fact that AIDS is a disease transmitted sexually and that the disease has hit fringe groups such as homosexuals and intravenous drug users the hardest. The HIV epidemic itself is divided sharply by geography, racial, and gender lines. In the U.S., minorities and intravenous drug users are disproportionately represented according to transmission. Blacks and Hispanics, while representing only 20% of the population, make up 40% of all AIDS cases in the U.S.. Distribution of AIDS cases among the states is similarly lopsided. There is also a great gap between awareness and action. Although 90% of the respondents in a national poll understood that transmission could come through intercourse or needle sharing with an infected individual, the same percentage believed that they were in a low or non-existent risk group. The prevention of the disease requires special attention to minorities; however, the misconception that AIDS is a minority disease is an incendiary one. The public and the medical community must recognize that anyone who engages in risky sexual or drug-related behavior is at risk. AIDS has placed economic, emotional and physical stress on our economy, our work and our lives; the question of how we will deal with this stress and how, as a society, our attitudes will change still remains. ",
 "Cancer is the leading cause of death for HIV-infected persons in economically developed countries, even in the era of antiretroviral therapy (ART). Lymphomas remain a leading cause of cancer morbidity and mortality for HIV-infected patients and have increased incidence even in patients optimally treated with ART. Even limited interruptions of ART can lead to CD4 cell nadirs and HIV viremia, and increase the risk of lymphoma. The treatment of lymphoma is now similar for HIV-infected patients and the general population: patients with good HIV control can withstand intensive therapies appropriate to the lymphoma, including autologous and even allogeneic hematopoietic stem cell transplantation. Nonetheless, HIV-related lymphomas have unique aspects, including differences in lymphoma pathogenesis, driven by the presence of HIV, in addition to coinfection with oncogenic viruses. These differences might be exploited in the future to inform therapies. The relative incidences of lymphoma subtypes also differ in the HIV-infected population, and the propensity to advanced stage, aggressive presentation, and extranodal disease is higher. Other unique aspects include the need to avoid potential interactions between ART and chemotherapeutic agents, and the need for HIV-specific supportive care, such as infection prophylaxis. Despite these specific challenges for cancer treatment in the setting of HIV infection, the care of these patients has progressed sufficiently that recent guidelines from the American Society of Clinical Oncology advocate the inclusion of HIV-infected patients alongside HIV- patients in cancer clinical trials when appropriate. ",
 "HIV is a devastating disease affecting millions of people worldwide despite the advent of successful antiretroviral therapy (ART). However, ART does not result in a cure and has to be taken for life. Accordingly, researchers are turning towards cure efforts, particularly in the light of two patients whose HIV has been seemingly eradicated. Numerous approaches and strategies have been considered for curing HIV, but no scalable and safe solution has yet been reached. With newly discovered difficulties in measuring the HIV reservoir, the main barrier to a cure, the only true test of cure is to stop ART and see whether the virus becomes detectable. However, it is possible that this treatment interruption may be associated with certain risks for patients. Here, we compare the current major approaches and recent advances for curing HIV, as well as discuss ways of evaluating HIV cure and the safety concerns involved. ",
 "Combination antiretroviral therapy (ART) has significantly reduced the morbidity and mortality resulting from HIV infection. ART is, however, unable to eradicate HIV, which persists latently in several cell types and tissues. Phylogenetic analyses suggested that the proliferation of cells infected before ART initiation is mainly responsible for residual viremia, although controversy still exists. Conversely, it is widely accepted that drug resistance mutations (DRMs) do not appear during ART in patients with suppressed viral loads. Studies based on sequence clustering have in fact indicated that, at least in developed countries, HIV-infected ART-naive patients are the major source of drug-resistant viruses. Analysis of longitudinally sampled sequences have also shown that DRMs have variable fitness costs, which are strongly influenced by the viral genetic background. "
 ]

# %%
# %%time
linked_docs = []
for doc in docs :
    linked_docs.append(e_linker.link_entities(doc))
# Out:
# 2021-12-14 16:52:54,878 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2021-12-14 16:52:54,879 Ignore 1 sentence(s) with no tokens.
# 2021-12-14 16:52:54,954 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2021-12-14 16:52:54,955 Ignore 1 sentence(s) with no tokens.
# 2021-12-14 16:52:55,014 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2021-12-14 16:52:55,015 Ignore 1 sentence(s) with no tokens.
# 2021-12-14 16:52:55,075 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2021-12-14 16:52:55,076 Ignore 1 sentence(s) with no tokens.
# 2021-12-14 16:52:55,111 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2021-12-14 16:52:55,112 Ignore 1 sentence(s) with no tokens.
# 2021-12-14 16:52:55,189 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2021-12-14 16:52:55,190 Ignore 1 sentence(s) with no tokens.
# 2021-12-14 16:52:55,254 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2021-12-14 16:52:55,255 Ignore 1 sentence(s) with no tokens.
# 2021-12-14 16:52:55,335 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2021-12-14 16:52:55,336 Ignore 1 sentence(s) with no tokens.
# 2021-12-14 16:52:55,378 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2021-12-14 16:52:55,380 Ignore 1 sentence(s) with no tokens.
# CPU times: user 427 ms, sys: 121 ms, total: 548 ms
# Wall time: 544 ms

# %%
linked_docs
# Out:
# [[{'start_pos': 5,
#    'end_pos': 10,
#    'text': 'virus',
#    'entities': [['NCBITaxon:10239', 0.9909885886035129, 'viruses'],
#     ['SIO:010379', 0.009034000186803164, 'virus']],
#    'best_entity': ('NCBITaxon:10239', 0.9909885886035129)},
#   {'start_pos': 40,
#    'end_pos': 45,
#    'text': 'virus',
#    'entities': [['NCBITaxon:10239', 0.9909885886035129, 'viruses'],
#     ['SIO:010379', 0.009034000186803164, 'virus']],
#    'best_entity': ('NCBITaxon:10239', 0.9909885886035129)},
#   {'text': 'genus',
#    'end_pos': 70,
#    'start_pos': 65,
#    'entities': [['NCBITaxon:genus', 1.036875205523338, 'genus']],
#    'best_entity': ('NCBITaxon:genus', 1.036875205523338)},
#   {'start_pos': 90,
#    'text': 'family',
#    'end_pos': 96,
#    'entities': [['NCBITaxon:family', 0.3419972596866919, 'family'],
#     ['SIO:001063', 0.3419972596866919, 'family'],
#     ['STATO:0000257',
#      0.6839746230331244,
#      'common linked ancestor number demonstrated group stipulated groups descent adoption family domestic marriage']],
#    'best_entity': ('STATO:0000257', 0.6839746230331244)},
#   {'end_pos': 158,
#    'text': 'primate',
#    'start_pos': 151,
#    'entities': [['NCBITaxon:9443', 0.9999975757726358, 'primates']],
#    'best_entity': ('NCBITaxon:9443', 0.9999975757726358)},
#   {'start_pos': 229,
#    'text': 'humans',
#    'end_pos': 235,
#    'entities': [['NCBITaxon:9605', 0.9999975757726358, 'homo']],
#    'best_entity': ('NCBITaxon:9605', 0.9999975757726358)},
#   {'end_pos': 249,
#    'text': 'sporadic',
#    'start_pos': 241,
#    'entities': [['PATO:0000428',
#      1.029905451112198,
#      'inhering process instances virtue single unpredictable quality sporadic bearer']],
#    'best_entity': ('PATO:0000428', 1.029905451112198)},
#   {'text': 'century',
#    'end_pos': 268,
#    'start_pos': 261,
#    'entities': [['SIO:000431', 1.036875205523338, 'century']],
#    'best_entity': ('SIO:000431', 1.036875205523338)},
#   {'end_pos': 357,
#    'start_pos': 353,
#    'text': 'bite',
#    'entities': [['UBERON:0035942',
#      1.036850070967433,
#      'upper formed biting bite teeth lower jaw space including jaws skeleton']],
#    'best_entity': ('UBERON:0035942', 1.036850070967433)},
#   {'text': 'fever',
#    'end_pos': 421,
#    'start_pos': 416,
#    'entities': [['CSSO:000121', 0.6797430002637733, 'fever'],
#     ['HP:0001945',
#      0.5097985993859652,
#      'body hyperthermia range temperature normal pyrexia elevated fever']],
#    'best_entity': ('CSSO:000121', 0.6797430002637733)},
#   {'text': 'infectious',
#    'end_pos': 480,
#    'start_pos': 470,
#    'entities': [['EFO:0005741',
#      1.0265496663627367,
#      'indirect direct diseases viral presence agent infectious disorder manifestations clinical parasitic resulting activity microbial transmitted disease communicable contact transmissible infection']],
#    'best_entity': ('EFO:0005741', 1.0265496663627367)},
#   {'text': 'diseases',
#    'start_pos': 481,
#    'end_pos': 489,
#    'entities': [['EFO:0000408', 0.9999975757726358, 'disease']],
#    'best_entity': ('EFO:0000408', 0.9999975757726358)},
#   {'start_pos': 535,
#    'end_pos': 541,
#    'text': 'dengue',
#    'entities': [['EFO:0005547',
#      1.1207729290019695,
#      'dhf syndrome dss non febrile disorder break infectious manifesting illness fever severe caused df bone arboviral philippine initial leakage dengue hemorrhage capillary thai shock progress breakbone forms singapore characterized specific disease hemorrhagic classic classical infection virus']],
#    'best_entity': ('EFO:0005547', 1.1207729290019695)},
#   {'text': 'infection',
#    'end_pos': 573,
#    'start_pos': 564,
#    'entities': [['EFO:0000544', 0.6839945193733843, 'infection'],
#     ['EFO:0005741',
#      217.9707124910211,
#      'indirect direct diseases viral presence agent infectious disorder manifestations clinical parasitic resulting activity microbial transmitted disease communicable contact transmissible infection']],
#    'best_entity': ('EFO:0005741', 217.9707124910211)},
#   {'text': 'associated',
#    'end_pos': 588,
#    'start_pos': 578,
#    'entities': [['PATO:0001668',
#      1.029900458142624,
#      'quality close virtue interacting inhering physically entity proximity structural associated bearer']],
#    'best_entity': ('PATO:0001668', 1.029900458142624)},
#   {'end_pos': 603,
#    'text': 'mild',
#    'start_pos': 599,
#    'entities': [['SIO:001213', 1.0368752055233381, 'mild']],
#    'best_entity': ('SIO:001213', 1.0368752055233381)},
#   {'start_pos': 625,
#    'text': 'large',
#    'end_pos': 630,
#    'entities': [['PATO:0000586',
#      1.0259693952601776,
#      'big expanded relatively increased large enlarged quality great high size']],
#    'best_entity': ('PATO:0000586', 1.0259693952601776)},
#   {'text': 'severe',
#    'end_pos': 687,
#    'start_pos': 681,
#    'entities': [['SIO:001215', 1.0368752055233381, 'severe']],
#    'best_entity': ('SIO:001215', 1.0368752055233381)},
#   {'text': 'severe',
#    'end_pos': 790,
#    'start_pos': 784,
#    'entities': [['SIO:001215', 1.0368752055233381, 'severe']],
#    'best_entity': ('SIO:001215', 1.0368752055233381)},
#   {'text': 'congenital',
#    'end_pos': 801,
#    'start_pos': 791,
#    'entities': [['MONDO:0021140',
#      1.036857611006338,
#      'congenital birth characteristic regardless present inborn disease cause']],
#    'best_entity': ('MONDO:0021140', 1.036857611006338)},
#   {'start_pos': 817,
#    'end_pos': 829,
#    'text': 'microcephaly',
#    'entities': [['HP:0000252',
#      0.6127200032767077,
#      'deviations skull standard age mean gender abnormally circumference head size reduced microcephaly decreased 2 calvarium small cranium'],
#     ['MONDO:0001149',
#      1.694183464823685,
#      'disorder microencephaly age normal person developmental circumference head microcephalus congenital acquired microcephaly smaller disease sex'],
#     ['MP:0000433',
#      0.20424495183091373,
#      'reduced microcephaly decreased small head abnormally size']],
#    'best_entity': ('MONDO:0001149', 1.694183464823685)},
#   {'text': 'associated',
#    'end_pos': 857,
#    'start_pos': 847,
#    'entities': [['PATO:0001668',
#      1.029900458142624,
#      'quality close virtue interacting inhering physically entity proximity structural associated bearer']],
#    'best_entity': ('PATO:0001668', 1.029900458142624)},
#   {'text': 'diagnosis',
#    'start_pos': 880,
#    'end_pos': 889,
#    'entities': [['SIO:001331', 1.0368752055233381, 'diagnosis']],
#    'best_entity': ('SIO:001331', 1.0368752055233381)},
#   {'text': 'fever',
#    'end_pos': 903,
#    'start_pos': 898,
#    'entities': [['CSSO:000121', 0.6797430002637733, 'fever'],
#     ['HP:0001945',
#      0.5097985993859652,
#      'body hyperthermia range temperature normal pyrexia elevated fever']],
#    'best_entity': ('CSSO:000121', 0.6797430002637733)},
#   {'end_pos': 919,
#    'start_pos': 914,
#    'text': 'virus',
#    'entities': [['NCBITaxon:10239', 0.9909885886035129, 'viruses'],
#     ['SIO:010379', 0.009034000186803164, 'virus']],
#    'best_entity': ('NCBITaxon:10239', 0.9909885886035129)},
#   {'text': 'diagnosis',
#    'end_pos': 986,
#    'start_pos': 977,
#    'entities': [['SIO:001331', 1.0368752055233381, 'diagnosis']],
#    'best_entity': ('SIO:001331', 1.0368752055233381)},
#   {'end_pos': 1021,
#    'start_pos': 1011,
#    'text': 'reactivity',
#    'entities': [['PATO:0000077',
#      1.0195897842509158,
#      'response agent react quality virtue disposition inhering responsivity stimulus reactivity bearer']],
#    'best_entity': ('PATO:0000077', 1.0195897842509158)},
#   {'text': 'genus',
#    'start_pos': 1054,
#    'end_pos': 1059,
#    'entities': [['NCBITaxon:genus', 1.036875205523338, 'genus']],
#    'best_entity': ('NCBITaxon:genus', 1.036875205523338)},
#   {'end_pos': 1118,
#    'start_pos': 1112,
#    'text': 'humans',
#    'entities': [['NCBITaxon:9605', 0.9999975757726358, 'homo']],
#    'best_entity': ('NCBITaxon:9605', 0.9999975757726358)},
#   {'end_pos': 1148,
#    'start_pos': 1141,
#    'text': 'vectors',
#    'entities': [['NCBITaxon:29278', 1.0000194777932747, 'vectors']],
#    'best_entity': ('NCBITaxon:29278', 1.0000194777932747)},
#   {'text': 'areas',
#    'end_pos': 1166,
#    'start_pos': 1161,
#    'entities': [['NCBITaxon:695168', 1.0232827322342892, 'areas']],
#    'best_entity': ('NCBITaxon:695168', 1.0232827322342892)},
#   {'end_pos': 1179,
#    'start_pos': 1173,
#    'text': 'dengue',
#    'entities': [['EFO:0005547',
#      1.1207729290019695,
#      'dhf syndrome dss non febrile disorder break infectious manifesting illness fever severe caused df bone arboviral philippine initial leakage dengue hemorrhage capillary thai shock progress breakbone forms singapore characterized specific disease hemorrhagic classic classical infection virus']],
#    'best_entity': ('EFO:0005547', 1.1207729290019695)},
#   {'end_pos': 1218,
#    'start_pos': 1209,
#    'text': 'incidence',
#    'entities': [['PATO:0000057',
#      0.9618528678410765,
#      'inhering virtue single occurrence temporal quality process incidence bearer'],
#     ['STATO:0000413',
#      0.048092643392053824,
#      'new risk number disease incidence cases divided persons ratio']],
#    'best_entity': ('PATO:0000057', 0.9618528678410765)},
#   {'start_pos': 1380,
#    'end_pos': 1387,
#    'text': 'vectors',
#    'entities': [['NCBITaxon:29278', 1.0000194777932747, 'vectors']],
#    'best_entity': ('NCBITaxon:29278', 1.0000194777932747)}],
#  [{'start_pos': 5,
#    'end_pos': 10,
#    'text': 'virus',
#    'entities': [['NCBITaxon:10239', 0.9941327257482806, 'viruses'],
#     ['SIO:010379', 0.009038472338747142, 'virus']],
#    'best_entity': ('NCBITaxon:10239', 0.9941327257482806)},
#   {'end_pos': 40,
#    'start_pos': 30,
#    'text': 'flavivirus',
#    'entities': [['NCBITaxon:11051',
#      1.001480393062798,
#      'b flavivirus group arboviruses']],
#    'best_entity': ('NCBITaxon:11051', 1.001480393062798)},
#   {'text': 'focus',
#    'start_pos': 53,
#    'end_pos': 58,
#    'entities': [['PATO:0001516',
#      1.0274757640187506,
#      'object focus originating converge rays quality optical light point']],
#    'best_entity': ('PATO:0001516', 1.0274757640187506)},
#   {'text': 'ongoing',
#    'start_pos': 65,
#    'end_pos': 72,
#    'entities': [['SIO:000035', 1.0436019803302905, 'ongoing']],
#    'best_entity': ('SIO:000035', 1.0436019803302905)},
#   {'end_pos': 99,
#    'start_pos': 93,
#    'text': 'health',
#    'entities': [['PATO:0000461',
#      0.9999790486765804,
#      'inhering virtue exhibiting deviation average normal quality bearer']],
#    'best_entity': ('PATO:0000461', 0.9999790486765804)},
#   {'text': 'sporadic',
#    'start_pos': 133,
#    'end_pos': 141,
#    'entities': [['PATO:0000428',
#      1.0353412790436247,
#      'inhering process instances virtue single unpredictable quality sporadic bearer']],
#    'best_entity': ('PATO:0000428', 1.0353412790436247)},
#   {'end_pos': 195,
#    'start_pos': 190,
#    'text': 'virus',
#    'entities': [['NCBITaxon:10239', 0.9941327257482806, 'viruses'],
#     ['SIO:010379', 0.009038472338747142, 'virus']],
#    'best_entity': ('NCBITaxon:10239', 0.9941327257482806)},
#   {'end_pos': 285,
#    'start_pos': 280,
#    'text': 'virus',
#    'entities': [['NCBITaxon:10239', 0.9941327257482806, 'viruses'],
#     ['SIO:010379', 0.009038472338747142, 'virus']],
#    'best_entity': ('NCBITaxon:10239', 0.9941327257482806)},
#   {'text': 'mild',
#    'start_pos': 333,
#    'end_pos': 337,
#    'entities': [['SIO:001213', 1.0436019803302905, 'mild']],
#    'best_entity': ('SIO:001213', 1.0436019803302905)},
#   {'text': 'influenza',
#    'end_pos': 347,
#    'start_pos': 338,
#    'entities': [['EFO:0007328',
#      0.8814835210103815,
#      'tract occurring lasts different days pharynx acute influenza viral c headache flu non disorder 3 prostration manifestations day fever b conjunctiva nos caused nasal strains viruses chills epidemics 10 myocardium isolated influenzaviruses myalgia marked cases inflammation usually human serologically designated incubation occasionally mucosa nervous central pandemics manifestation period involvement system respiratory infection'],
#     ['DOID:8469', 0.17052626711456564, 'influenza']],
#    'best_entity': ('EFO:0007328', 0.8814835210103815)},
#   {'text': 'severe',
#    'start_pos': 362,
#    'end_pos': 368,
#    'entities': [['SIO:001215', 1.0436019803302905, 'severe']],
#    'best_entity': ('SIO:001215', 1.0436019803302905)},
#   {'start_pos': 430,
#    'text': 'syndrome',
#    'end_pos': 438,
#    'entities': [['DOID:225', 0.9398577406685151, 'syndrome'],
#     ['MONDO:0002254',
#      80.4975268188408,
#      'syndrome abnormal cluster syndromes disorder genetic signs collectively symptoms clusters characteristics define condition symptom clinicopathological basis group associated disease syndromic'],
#     ['SIO:001017', 0.03480954595068574, 'syndrome']],
#    'best_entity': ('MONDO:0002254', 80.4975268188408)},
#   {'start_pos': 442,
#    'text': 'adults',
#    'end_pos': 448,
#    'entities': [['UBERON:0007023',
#      1.030682409379046,
#      'adults existence_starts_with adult organism multicellular existence_ends_with juvenile post stage']],
#    'best_entity': ('UBERON:0007023', 1.030682409379046)},
#   {'end_pos': 465,
#    'start_pos': 453,
#    'text': 'microcephaly',
#    'entities': [['HP:0000252',
#      0.6150221350908753,
#      'deviations skull standard age mean gender abnormally circumference head size reduced microcephaly decreased 2 calvarium small cranium'],
#     ['MONDO:0001149',
#      1.6400676163425676,
#      'disorder microencephaly age normal person developmental circumference head microcephalus congenital acquired microcephaly smaller disease sex'],
#     ['MP:0000433',
#      0.20501274703055508,
#      'reduced microcephaly decreased small head abnormally size']],
#    'best_entity': ('MONDO:0001149', 1.6400676163425676)},
#   {'end_pos': 532,
#    'text': 'treatment',
#    'start_pos': 523,
#    'entities': [['EFO:0000727', 1.0079644332686535, 'treatment']],
#    'best_entity': ('EFO:0000727', 1.0079644332686535)},
#   {'start_pos': 569,
#    'end_pos': 574,
#    'text': 'virus',
#    'entities': [['NCBITaxon:10239', 0.9941327257482806, 'viruses'],
#     ['SIO:010379', 0.009038472338747142, 'virus']],
#    'best_entity': ('NCBITaxon:10239', 0.9941327257482806)},
#   {'end_pos': 604,
#    'start_pos': 598,
#    'text': 'health',
#    'entities': [['PATO:0000461',
#      0.9999790486765804,
#      'inhering virtue exhibiting deviation average normal quality bearer']],
#    'best_entity': ('PATO:0000461', 0.9999790486765804)},
#   {'text': 'response',
#    'start_pos': 605,
#    'end_pos': 613,
#    'entities': [['PATO:0000077',
#      1.023130807661131,
#      'response agent react quality virtue disposition inhering responsivity stimulus reactivity bearer']],
#    'best_entity': ('PATO:0000077', 1.023130807661131)},
#   {'end_pos': 655,
#    'text': 'infection',
#    'start_pos': 646,
#    'entities': [['EFO:0000544', 0.687136002517364, 'infection'],
#     ['EFO:0005741',
#      218.84192768301273,
#      'indirect direct diseases viral presence agent infectious disorder manifestations clinical parasitic resulting activity microbial transmitted disease communicable contact transmissible infection']],
#    'best_entity': ('EFO:0005741', 218.84192768301273)},
#   {'start_pos': 726,
#    'end_pos': 731,
#    'text': 'virus',
#    'entities': [['NCBITaxon:10239', 0.9941327257482806, 'viruses'],
#     ['SIO:010379', 0.009038472338747142, 'virus']],
#    'best_entity': ('NCBITaxon:10239', 0.9941327257482806)},
#   {'end_pos': 769,
#    'start_pos': 764,
#    'text': 'virus',
#    'entities': [['NCBITaxon:10239', 0.9941327257482806, 'viruses'],
#     ['SIO:010379', 0.009038472338747142, 'virus']],
#    'best_entity': ('NCBITaxon:10239', 0.9941327257482806)},
#   {'start_pos': 772,
#    'end_pos': 779,
#    'text': 'vectors',
#    'entities': [['NCBITaxon:29278', 1.000023194110108, 'vectors']],
#    'best_entity': ('NCBITaxon:29278', 1.000023194110108)},
#   {'start_pos': 796,
#    'end_pos': 808,
#    'text': 'pathogenesis',
#    'entities': [['GO:0001897',
#      0.2550472234273019,
#      'cell cytolysis cells loss larger killing pathogenesis organism rupture defined host interaction symbiotic organisms symbiont means membranes involved cytoplasm'],
#     ['GO:0001907',
#      1.1477215216215586,
#      'involved cells mediated larger killing pathogenesis organism defined host interaction symbiotic results organisms symbiont death process'],
#     ['GO:0019836',
#      0.12752127432810648,
#      'destruction cytolysis hemoglobin release cells intracellular hemolysin larger haemolysis pathogenesis cytolytic blood organism defined host rbcs hemolysis interaction symbiotic erythrocytes organisms activity red symbiont regulation involved'],
#     ['GO:0044003',
#      33.66632164967887,
#      'cell biological disruption structure morphology change pathogenesis modification processes modulation organism host physiology symbiont effects regulation system process'],
#     ['GO:0052031',
#      7.437155441680317,
#      'involved response rate presence larger pathogenesis modulation organism defined modulates host extent interaction symbiotic organisms mitigation symbiont mounted defense frequency process'],
#     ['GO:0052042',
#      0.8926419085824244,
#      'involved cell activates rate apoptotic induction non positive larger increases pathogenesis programmed organism defined host extent activation interaction symbiotic organisms symbiont maintains enhancement regulation death frequency stimulation process upregulation'],
#     ['GO:0009405',
#      0.12752561535128212,
#      'detrimental abnormal induce pathogenesis processes virulence organism ability state set generate specific generally']],
#    'best_entity': ('GO:0044003', 33.66632164967887)},
#   {'text': 'genetic',
#    'end_pos': 817,
#    'start_pos': 810,
#    'entities': [['MONDO:0021152',
#      1.0435773827835044,
#      'constitutitional problem inherited genetic characteristic parents familial hereditary disease cause']],
#    'best_entity': ('MONDO:0021152', 1.0435773827835044)},
#   {'end_pos': 868,
#    'text': 'co',
#    'start_pos': 866,
#    'entities': [['CHEBI:17245',
#      0.34104003019908713,
#      'inchi=1 ugfairiumavxcw co. c1 2 monoxide oxide formula carbon(ii monooxide uhfffaoyat inchikey = co carbon'],
#     ['CHEBI:27638',
#      0.3410427094481516,
#      'cobalt atomic 27 atom kobalt number 27co cobalto group element co cobaltum'],
#     ['CHEBI:17790',
#      0.16666011966723443,
#      'simplest aliphatic methylalkohol wood ch3oh meoh methanol primary spirit comprising carbinol alcohol group methyl naphtha'],
#     ['EFO:0005176', 0.3410498546081656, 'arabidopsis coimbra ecotype co']],
#    'best_entity': ('EFO:0005176', 0.3410498546081656)},
#   {'end_pos': 878,
#    'text': 'infection',
#    'start_pos': 869,
#    'entities': [['EFO:0000544', 0.687136002517364, 'infection'],
#     ['EFO:0005741',
#      218.84192768301273,
#      'indirect direct diseases viral presence agent infectious disorder manifestations clinical parasitic resulting activity microbial transmitted disease communicable contact transmissible infection']],
#    'best_entity': ('EFO:0005741', 218.84192768301273)},
#   {'start_pos': 902,
#    'text': 'viruses',
#    'end_pos': 909,
#    'entities': [['NCBITaxon:10239', 1.0031702959823559, 'viruses']],
#    'best_entity': ('NCBITaxon:10239', 1.0031702959823559)},
#   {'start_pos': 985,
#    'end_pos': 992,
#    'text': 'patient',
#    'entities': [['SIO:000393', 1.0436019803302905, 'patient']],
#    'best_entity': ('SIO:000393', 1.0436019803302905)},
#   {'end_pos': 1022,
#    'start_pos': 1016,
#    'text': 'health',
#    'entities': [['PATO:0000461',
#      0.9999790486765804,
#      'inhering virtue exhibiting deviation average normal quality bearer']],
#    'best_entity': ('PATO:0000461', 0.9999790486765804)},
#   {'text': 'intervention',
#    'start_pos': 1023,
#    'end_pos': 1035,
#    'entities': [['EFO:0002571',
#      1.0508337301295056,
#      'procedures preventive interventional encompasses patient intended behavioral interventiondescription procedure environmental surgical produces course acts intervention strategies general term activity population palliative medical therapeutic alter effects effect disease social']],
#    'best_entity': ('EFO:0002571', 1.0508337301295056)},
#   {'end_pos': 1061,
#    'start_pos': 1056,
#    'text': 'virus',
#    'entities': [['NCBITaxon:10239', 0.9941327257482806, 'viruses'],
#     ['SIO:010379', 0.009038472338747142, 'virus']],
#    'best_entity': ('NCBITaxon:10239', 0.9941327257482806)}],
#  [{'start_pos': 22,
#    'end_pos': 27,
#    'text': 'virus',
#    'entities': [['NCBITaxon:10239', 0.9939898167347545, 'viruses'],
#     ['SIO:010379', 0.009037132035400748, 'virus']],
#    'best_entity': ('NCBITaxon:10239', 0.9939898167347545)},
#   {'start_pos': 40,
#    'text': 'major',
#    'end_pos': 45,
#    'entities': [['NCBITaxon:1925465', 1.0337288796777198, 'major']],
#    'best_entity': ('NCBITaxon:1925465', 1.0337288796777198)},
#   {'start_pos': 53,
#    'end_pos': 59,
#    'text': 'health',
#    'entities': [['PATO:0000461',
#      0.99998091003672,
#      'inhering virtue exhibiting deviation average normal quality bearer']],
#    'best_entity': ('PATO:0000461', 0.99998091003672)},
#   {'end_pos': 78,
#    'start_pos': 71,
#    'text': 'focused',
#    'entities': [['PATO:0001517',
#      1.041562161796907,
#      'inhering virtue focus having focused quality optical bearer']],
#    'best_entity': ('PATO:0001517', 1.041562161796907)},
#   {'end_pos': 110,
#    'start_pos': 105,
#    'text': 'virus',
#    'entities': [['NCBITaxon:10239', 0.9939898167347545, 'viruses'],
#     ['SIO:010379', 0.009037132035400748, 'virus']],
#    'best_entity': ('NCBITaxon:10239', 0.9939898167347545)},
#   {'start_pos': 160,
#    'text': 'disease',
#    'end_pos': 167,
#    'entities': [['EFO:0000408', 0.9996407873694892, 'disease'],
#     ['DOID:4', 0.011105596458226393, 'disease'],
#     ['OGMS:0000031',
#      0.00013710351178910794,
#      'disorders processes disposition pathological organism exists ii disease undergo'],
#     ['SIO:010299', 0.00013710612911390607, 'disease']],
#    'best_entity': ('EFO:0000408', 0.9996407873694892)},
#   {'text': 'intervention',
#    'start_pos': 168,
#    'end_pos': 180,
#    'entities': [['EFO:0002571',
#      1.0066691225443924,
#      'procedures preventive interventional encompasses patient intended behavioral interventiondescription procedure environmental surgical produces course acts intervention strategies general term activity population palliative medical therapeutic alter effects effect disease social']],
#    'best_entity': ('EFO:0002571', 1.0066691225443924)},
#   {'start_pos': 242,
#    'text': 'structure',
#    'end_pos': 251,
#    'entities': [['PATO:0000141',
#      0.8918565568467238,
#      'structure morphology quality form arrangements connectivity virtue relative relational position organism parts inhering pattern conformation structural shape underlying bearer'],
#     ['SIO:000600', 0.6370677593799408, 'structure']],
#    'best_entity': ('PATO:0000141', 0.8918565568467238)},
#   {'text': 'function',
#    'end_pos': 260,
#    'start_pos': 252,
#    'entities': [['BFO:0000034', 0.8517446327212973, 'function'],
#     ['SIO:000017', 0.17034892654425943, 'function']],
#    'best_entity': ('BFO:0000034', 0.8517446327212973)},
#   {'end_pos': 336,
#    'start_pos': 330,
#    'text': 'mature',
#    'entities': [['PATO:0001701',
#      1.0337066794600434,
#      'mature differentiation inhering virtue complete development exhibiting growth quality bearer']],
#    'best_entity': ('PATO:0001701', 1.0337066794600434)},
#   {'text': 'immature',
#    'start_pos': 341,
#    'end_pos': 349,
#    'entities': [['PATO:0001501',
#      1.026206795113481,
#      'differentiation inhering virtue complete development immature lacking quality growth underdeveloped bearer']],
#    'best_entity': ('PATO:0001501', 1.026206795113481)},
#   {'end_pos': 432,
#    'start_pos': 426,
#    'text': 'dengue',
#    'entities': [['EFO:0005547',
#      1.036928211615476,
#      'dhf syndrome dss non febrile disorder break infectious manifesting illness fever severe caused df bone arboviral philippine initial leakage dengue hemorrhage capillary thai shock progress breakbone forms singapore characterized specific disease hemorrhagic classic classical infection virus']],
#    'best_entity': ('EFO:0005547', 1.036928211615476)},
#   {'start_pos': 447,
#    'text': 'viruses',
#    'end_pos': 454,
#    'entities': [['NCBITaxon:10239', 1.0030260877959796, 'viruses']],
#    'best_entity': ('NCBITaxon:10239', 1.0030260877959796)},
#   {'end_pos': 535,
#    'text': 'structure',
#    'start_pos': 526,
#    'entities': [['PATO:0000141',
#      0.8918565568467238,
#      'structure morphology quality form arrangements connectivity virtue relative relational position organism parts inhering pattern conformation structural shape underlying bearer'],
#     ['SIO:000600', 0.6370677593799408, 'structure']],
#    'best_entity': ('PATO:0000141', 0.8918565568467238)},
#   {'text': 'flavivirus',
#    'start_pos': 561,
#    'end_pos': 571,
#    'entities': [['NCBITaxon:11051',
#      1.001413510128043,
#      'b flavivirus group arboviruses']],
#    'best_entity': ('NCBITaxon:11051', 1.001413510128043)},
#   {'text': 'address',
#    'start_pos': 609,
#    'end_pos': 616,
#    'entities': [['SIO:000172', 1.0415795599817852, 'address']],
#    'best_entity': ('SIO:000172', 1.0415795599817852)},
#   {'start_pos': 630,
#    'end_pos': 638,
#    'text': 'receptor',
#    'entities': [['SIO:010420', 1.0415795599817852, 'receptor']],
#    'best_entity': ('SIO:010420', 1.0415795599817852)},
#   {'start_pos': 754,
#    'end_pos': 764,
#    'text': 'antibodies',
#    'entities': [['EFO:0000264',
#      1.0677674469811624,
#      'antigen microorganisms toxins function fighting antibody blood fluids pathogenic viruses secretory protein destroy helps molecule binding tags bacteria neutralizes antibodies infection']],
#    'best_entity': ('EFO:0000264', 1.0677674469811624)},
#   {'text': 'great',
#    'end_pos': 796,
#    'start_pos': 791,
#    'entities': [['PATO:0000586',
#      1.02926614289952,
#      'big expanded relatively increased large enlarged quality great high size']],
#    'best_entity': ('PATO:0000586', 1.02926614289952)},
#   {'text': 'host',
#    'start_pos': 869,
#    'end_pos': 873,
#    'entities': [['EFO:0000532',
#      0.5168533397300217,
#      'parasite thereof plant natural animal lab supports host environment nourishes'],
#     ['SIO:010415', 0.51686443983886, 'host']],
#    'best_entity': ('SIO:010415', 0.51686443983886)},
#   {'start_pos': 935,
#    'end_pos': 942,
#    'text': 'tropism',
#    'entities': [['GO:0009606',
#      1.0181912037851748,
#      'response source external organism movement usually stimulus tropism away']],
#    'best_entity': ('GO:0009606', 1.0181912037851748)},
#   {'start_pos': 969,
#    'end_pos': 981,
#    'text': 'pathogenesis',
#    'entities': [['GO:0001897',
#      0.26341145126087084,
#      'cell cytolysis cells loss larger killing pathogenesis organism rupture defined host interaction symbiotic organisms symbiont means membranes involved cytoplasm'],
#     ['GO:0001907',
#      1.1853600152588548,
#      'involved cells mediated larger killing pathogenesis organism defined host interaction symbiotic results organisms symbiont death process'],
#     ['GO:0019836',
#      0.13170352605942906,
#      'destruction cytolysis hemoglobin release cells intracellular hemolysin larger haemolysis pathogenesis cytolytic blood organism defined host rbcs hemolysis interaction symbiotic erythrocytes organisms activity red symbiont regulation involved'],
#     ['GO:0044003',
#      35.441840309881385,
#      'cell biological disruption structure morphology change pathogenesis modification processes modulation organism host physiology symbiont effects regulation system process'],
#     ['GO:0052031',
#      7.507190538240845,
#      'involved response rate presence larger pathogenesis modulation organism defined modulates host extent interaction symbiotic organisms mitigation symbiont mounted defense frequency process'],
#     ['GO:0052042',
#      0.9219180841115426,
#      'involved cell activates rate apoptotic induction non positive larger increases pathogenesis programmed organism defined host extent activation interaction symbiotic organisms symbiont maintains enhancement regulation death frequency stimulation process upregulation'],
#     ['GO:0009405',
#      0.12740990352280288,
#      'detrimental abnormal induce pathogenesis processes virulence organism ability state set generate specific generally']],
#    'best_entity': ('GO:0044003', 35.441840309881385)},
#   {'text': 'virion',
#    'end_pos': 1181,
#    'start_pos': 1175,
#    'entities': [['GO:0044423',
#      1.0095813731947234,
#      'constituent component complete virion extracellular particle fully infectious virus']],
#    'best_entity': ('GO:0044423', 1.0095813731947234)},
#   {'start_pos': 1182,
#    'text': 'structure',
#    'end_pos': 1191,
#    'entities': [['PATO:0000141',
#      0.8918565568467238,
#      'structure morphology quality form arrangements connectivity virtue relative relational position organism parts inhering pattern conformation structural shape underlying bearer'],
#     ['SIO:000600', 0.6370677593799408, 'structure']],
#    'best_entity': ('PATO:0000141', 0.8918565568467238)},
#   {'text': 'function',
#    'start_pos': 1196,
#    'end_pos': 1204,
#    'entities': [['BFO:0000034', 0.8517446327212973, 'function'],
#     ['SIO:000017', 0.17034892654425943, 'function']],
#    'best_entity': ('BFO:0000034', 0.8517446327212973)}],
#  [{'end_pos': 18,
#    'text': 'syndrome',
#    'start_pos': 10,
#    'entities': [['DOID:225', 0.9434121418336633, 'syndrome'],
#     ['MONDO:0002254',
#      77.42698120757875,
#      'syndrome abnormal cluster syndromes disorder genetic signs collectively symptoms clusters characteristics define condition symptom clinicopathological basis group associated disease syndromic'],
#     ['SIO:001017', 0.03494119043828383, 'syndrome']],
#    'best_entity': ('MONDO:0002254', 77.42698120757875)},
#   {'text': 'severe',
#    'end_pos': 50,
#    'start_pos': 44,
#    'entities': [['SIO:001215', 1.0615724729750409, 'severe']],
#    'best_entity': ('SIO:001215', 1.0615724729750409)},
#   {'end_pos': 68,
#    'text': 'infection',
#    'start_pos': 59,
#    'entities': [['EFO:0000544', 0.6954999217136024, 'infection'],
#     ['EFO:0005741',
#      221.50900984430857,
#      'indirect direct diseases viral presence agent infectious disorder manifestations clinical parasitic resulting activity microbial transmitted disease communicable contact transmissible infection']],
#    'best_entity': ('EFO:0005741', 221.50900984430857)},
#   {'text': 'retrovirus',
#    'end_pos': 88,
#    'start_pos': 78,
#    'entities': [['NCBITaxon:31931',
#      1.0615705267898168,
#      'unidentified retrovirus']],
#    'best_entity': ('NCBITaxon:31931', 1.0615705267898168)},
#   {'text': 'malignant',
#    'end_pos': 138,
#    'start_pos': 129,
#    'entities': [['EFO:0006851',
#      1.061539390957876,
#      'cell abnormal control function spread malignant causing refers manifested host adverse growth activity decreased tissue effects surrounding tumor']],
#    'best_entity': ('EFO:0006851', 1.061539390957876)},
#   {'end_pos': 148,
#    'start_pos': 139,
#    'text': 'neoplasms',
#    'entities': [['EFO:0000616',
#      1.0621447996584392,
#      'cytologic cell neoplasms sarcomas cystadenomas cysts cells include benign malignant neopl features figures lymphomas signs dysplastic resemble nuclear neoplastic incl normal tumors neoplasia exhibit mitotic resulting polyps proliferation atypia carcinomas overt unspecified tumour representative tumours significant growth papillomas pleomorphism tissue neoplasm necrosis examples cellular exhibiting lipomas uncontrolled leukemias disease tumor atypical process anaplasia']],
#    'best_entity': ('EFO:0000616', 1.0621447996584392)},
#   {'start_pos': 215,
#    'text': 'date',
#    'end_pos': 219,
#    'entities': [['STATO:0000093',
#      1.0615549581370385,
#      'timestamp date year time indicating calendar event month day information']],
#    'best_entity': ('STATO:0000093', 1.0615549581370385)},
#   {'start_pos': 225,
#    'end_pos': 233,
#    'text': 'syndrome',
#    'entities': [['DOID:225', 0.9434121418336633, 'syndrome'],
#     ['MONDO:0002254',
#      77.42698120757875,
#      'syndrome abnormal cluster syndromes disorder genetic signs collectively symptoms clusters characteristics define condition symptom clinicopathological basis group associated disease syndromic'],
#     ['SIO:001017', 0.03494119043828383, 'syndrome']],
#    'best_entity': ('MONDO:0002254', 77.42698120757875)},
#   {'start_pos': 360,
#    'text': 'hepatitis',
#    'end_pos': 369,
#    'entities': [['HP:0012115',
#      0.6211710761131258,
#      'hepatitis liver inflammation'],
#     ['MP:0001860',
#      0.20705436832897228,
#      'fluid accumulation local hepatic plasma leukocytes hepatitis liver inflammation proteins'],
#     ['PDO:000148', 0.20705778456634288, 'hepatitis']],
#    'best_entity': ('HP:0012115', 0.6211710761131258)},
#   {'text': 'tumors',
#    'end_pos': 506,
#    'start_pos': 500,
#    'entities': [['EFO:0000616',
#      1.0621447996584392,
#      'cytologic cell neoplasms sarcomas cystadenomas cysts cells include benign malignant neopl features figures lymphomas signs dysplastic resemble nuclear neoplastic incl normal tumors neoplasia exhibit mitotic resulting polyps proliferation atypia carcinomas overt unspecified tumour representative tumours significant growth papillomas pleomorphism tissue neoplasm necrosis examples cellular exhibiting lipomas uncontrolled leukemias disease tumor atypical process anaplasia']],
#    'best_entity': ('EFO:0000616', 1.0621447996584392)},
#   {'start_pos': 552,
#    'end_pos': 561,
#    'text': 'pneumonia',
#    'entities': [['CSSO:000186', 0.17209533409801675, 'pneumonia'],
#     ['EFO:0003106',
#      4.847226821755954,
#      'affecting acute chronic lungs include headache disorder infectious fungi nos symptoms caused chest organism viruses chills sweating diffusely pain breath parenchyma fevers focally ambiguous specified lung organisms inflammation shortness weakness bacteria mycoplasma cough pneumonia disease pneumonitis infection'],
#     ['MP:0001861',
#      1.3767399576367514,
#      'fluid accumulation local plasma leukocytes pneumonia lung pulmonary inflammation proteins'],
#     ['MPATH:877',
#      0.5162755913080187,
#      'congestion affecting symptoms associated pneumonia chest lung condition inflammatory especially alveoli fever'],
#     ['PDO:000193', 1.376762672784134, 'pneumonia']],
#    'best_entity': ('EFO:0003106', 4.847226821755954)},
#   {'end_pos': 631,
#    'text': 'syndrome',
#    'start_pos': 623,
#    'entities': [['DOID:225', 0.9434121418336633, 'syndrome'],
#     ['MONDO:0002254',
#      77.42698120757875,
#      'syndrome abnormal cluster syndromes disorder genetic signs collectively symptoms clusters characteristics define condition symptom clinicopathological basis group associated disease syndromic'],
#     ['SIO:001017', 0.03494119043828383, 'syndrome']],
#    'best_entity': ('MONDO:0002254', 77.42698120757875)},
#   {'text': 'reduced',
#    'start_pos': 644,
#    'end_pos': 651,
#    'entities': [['PATO:0000587',
#      0.6211631049869167,
#      'low reduced decreased relatively tiny small quality underdeveloped hypoplasia size'],
#     ['PATO:0001997',
#      0.4141087366579445,
#      'low reduced decreased relatively subnumerary fewer present number organism numbers']],
#    'best_entity': ('PATO:0000587', 0.6211631049869167)}],
#  [{'start_pos': 30,
#    'end_pos': 37,
#    'text': 'segment',
#    'entities': [['UBERON:0000914',
#      1.0254531285343458,
#      'divisions serial repeated organismal organism element segment']],
#    'best_entity': ('UBERON:0000914', 1.0254531285343458)},
#   {'start_pos': 53,
#    'end_pos': 61,
#    'text': 'acquired',
#    'entities': [['MONDO:0021141',
#      1.0361258141587468,
#      'genetically acquired inherited']],
#    'best_entity': ('MONDO:0021141', 1.0361258141587468)},
#   {'start_pos': 62,
#    'end_pos': 78,
#    'text': 'immunodeficiency',
#    'entities': [['HP:0002721',
#      0.6836183641548228,
#      'insufficiency component deficiency function substance immunodeficiency failure absence adequately decreased body protect system process infection immune'],
#     ['MONDO:0021094',
#      48.57773847826604,
#      'syndrome mechanisms deficiency disorder defect immunodeficiency immunity humoral cellular disease immuno']],
#    'best_entity': ('MONDO:0021094', 48.57773847826604)},
#   {'start_pos': 79,
#    'end_pos': 87,
#    'text': 'syndrome',
#    'entities': [['DOID:225', 0.9383662493149758, 'syndrome'],
#     ['MONDO:0002254',
#      78.61837360288604,
#      'syndrome abnormal cluster syndromes disorder genetic signs collectively symptoms clusters characteristics define condition symptom clinicopathological basis group associated disease syndromic'],
#     ['SIO:001017', 0.03475430553018429, 'syndrome']],
#    'best_entity': ('MONDO:0002254', 78.61837360288604)},
#   {'text': 'diagnosis',
#    'end_pos': 133,
#    'start_pos': 124,
#    'entities': [['SIO:001331', 1.0361315589157774, 'diagnosis']],
#    'best_entity': ('SIO:001331', 1.0361315589157774)},
#   {'start_pos': 143,
#    'text': 'disease',
#    'end_pos': 150,
#    'entities': [['EFO:0000408', 0.9996333904821858, 'disease'],
#     ['DOID:4', 0.011105514281862166, 'disease'],
#     ['OGMS:0000031',
#      0.0001371020740295387,
#      'disorders processes disposition pathological organism exists ii disease undergo'],
#     ['SIO:010299', 0.00013710511459089092, 'disease']],
#    'best_entity': ('EFO:0000408', 0.9996333904821858)},
#   {'start_pos': 161,
#    'text': 'advanced',
#    'end_pos': 169,
#    'entities': [['PATO:0000694',
#      1.051559949906515,
#      'advanced premature natural precocious starts start early time reference quality process earlier']],
#    'best_entity': ('PATO:0000694', 1.051559949906515)},
#   {'start_pos': 170,
#    'text': 'stages',
#    'end_pos': 176,
#    'entities': [['ZFS:0100000', 1.0055303258227304, 'stages']],
#    'best_entity': ('ZFS:0100000', 1.0055303258227304)},
#   {'end_pos': 232,
#    'start_pos': 204,
#    'text': 'human immunodeficiency virus',
#    'entities': [['EFO:0000764',
#      0.922966625827448,
#      'aids syndrome human complex iii includes arc disorder infectious x]human infections t x]unspecified nos htlv range caused spectrum immunodeficiency asymptomatic unspecified type related lav dis hiv acquired wiii infect disease immuno lymphotropic infection seropositivity virus'],
#     ['NCBITaxon:12721',
#      0.1606996307015262,
#      'aids human immunodeficiency hiv virus']],
#    'best_entity': ('EFO:0000764', 0.922966625827448)},
#   {'start_pos': 251,
#    'text': 'chronic',
#    'end_pos': 258,
#    'entities': [['HP:0011010',
#      0.33974925610230305,
#      'progress slow chronic onset long continuance disease manifestations creeping'],
#     ['PATO:0000498',
#      0.5095968640558978,
#      'relatively increased duration chronic slow period prolonged time quality process high'],
#     ['PATO:0001863',
#      0.5095954514765206,
#      'inhering virtue duration slow chronic progressive indefinite having quality process course bearer']],
#    'best_entity': ('PATO:0000498', 0.5095968640558978)},
#   {'text': 'disease',
#    'start_pos': 273,
#    'end_pos': 280,
#    'entities': [['EFO:0000408', 0.9996333904821858, 'disease'],
#     ['DOID:4', 0.011105514281862166, 'disease'],
#     ['OGMS:0000031',
#      0.0001371020740295387,
#      'disorders processes disposition pathological organism exists ii disease undergo'],
#     ['SIO:010299', 0.00013710511459089092, 'disease']],
#    'best_entity': ('EFO:0000408', 0.9996333904821858)},
#   {'start_pos': 389,
#    'text': 'early',
#    'end_pos': 394,
#    'entities': [['PATO:0000694',
#      1.051559949906515,
#      'advanced premature natural precocious starts start early time reference quality process earlier']],
#    'best_entity': ('PATO:0000694', 1.051559949906515)},
#   {'text': 'diagnosis',
#    'start_pos': 395,
#    'end_pos': 404,
#    'entities': [['SIO:001331', 1.0361315589157774, 'diagnosis']],
#    'best_entity': ('SIO:001331', 1.0361315589157774)},
#   {'end_pos': 425,
#    'text': 'treatment',
#    'start_pos': 416,
#    'entities': [['EFO:0000727', 1.0066188609992524, 'treatment']],
#    'best_entity': ('EFO:0000727', 1.0066188609992524)},
#   {'text': 'diagnosis',
#    'start_pos': 512,
#    'end_pos': 521,
#    'entities': [['SIO:001331', 1.0361315589157774, 'diagnosis']],
#    'best_entity': ('SIO:001331', 1.0361315589157774)},
#   {'start_pos': 542,
#    'end_pos': 549,
#    'text': 'present',
#    'entities': [['PATO:0000467',
#      1.0149970034847131,
#      'existence inhering virtue present organism quality bearer']],
#    'best_entity': ('PATO:0000467', 1.0149970034847131)},
#   {'start_pos': 575,
#    'end_pos': 583,
#    'text': 'abnormal',
#    'entities': [['PATO:0000460',
#      0.8166265184517102,
#      'abnormal average quality deviation virtue normal defective inhering atypia aberrant atypical bearer'],
#     ['SIO:000555', 0.6124885652091855, 'abnormal']],
#    'best_entity': ('PATO:0000460', 0.8166265184517102)},
#   {'text': 'pap',
#    'end_pos': 587,
#    'start_pos': 584,
#    'entities': [['CHEBI:53758',
#      0.2041549319128515,
#      '3 propanediol phenylamino-1,2 anilino diol derivative glycerol anilinopropylene glycol replaced group groups hydroxy 3-(phenylamino)propane-1,2 pap'],
#     ['CHEBI:17985',
#      0.20415549780565018,
#      "3'-phosphoadenylate having monophosphate adenosine 5'-positions 3',5'-bisphosphate 3'- 3',5'-bis(dihydrogen groups 3',5'-bismonophosphate bisphosphate phosphate pap phosphoadenosine"],
#     ['MONDO:0001437',
#      0.8165789883122676,
#      'low filling stain dyspnea inhalation include mineral alveoli disorder proteinosis material positive fever signs symptoms stains pulmonary alveolar dusts secondary hematologic lung proteinaceous periodic acid schiff malignancies cough grade characterized idiopathic pap rare'],
#     ['GO:0043751',
#      0.20415606370567538,
#      'polyphosphate)n polyphosphate)n-1 reaction + adp ppt pap phosphotransferase polyphosphate activity = amp catalysis'],
#     ['MP:0010998',
#      0.2084013807484098,
#      'cell abnormal lipoproteinaceous lungs phospholipidosis proteinosis material amorphous accumulation largely cleared phospholipoproteinosis pulmonary alveolar lipoproteinosis intra easily surfactant like pap free']],
#    'best_entity': ('MONDO:0001437', 0.8165789883122676)},
#   {'text': 'diseases',
#    'end_pos': 628,
#    'start_pos': 620,
#    'entities': [['EFO:0000408', 1.0000447058259585, 'disease']],
#    'best_entity': ('EFO:0000408', 1.0000447058259585)},
#   {'text': 'severe',
#    'start_pos': 648,
#    'end_pos': 654,
#    'entities': [['SIO:001215', 1.0361315589157774, 'severe']],
#    'best_entity': ('SIO:001215', 1.0361315589157774)},
#   {'text': 'recurrent',
#    'end_pos': 665,
#    'start_pos': 656,
#    'entities': [['EFO:0010246',
#      0.5146806429972396,
#      'episodes individuals disease occur recurrent'],
#     ['PATO:0000427',
#      0.5146490747740645,
#      'inhering appearing occurring virtue single repeatedly quality process bearer recurrent']],
#    'best_entity': ('EFO:0010246', 0.5146806429972396)},
#   {'text': 'resistant',
#    'start_pos': 671,
#    'end_pos': 680,
#    'entities': [['PATO:0000513',
#      0.5146490747740646,
#      'resistant inhering stimulus virtue sensitivity lacking quality external bearer insensitive'],
#     ['PATO:0001178',
#      2.0586134187112037,
#      'resistant inhering stimulus virtue resistance quality bearer']],
#    'best_entity': ('PATO:0001178', 2.0586134187112037)},
#   {'end_pos': 693,
#    'start_pos': 684,
#    'text': 'treatment',
#    'entities': [['EFO:0000727', 1.0066188609992524, 'treatment']],
#    'best_entity': ('EFO:0000727', 1.0066188609992524)},
#   {'end_pos': 763,
#    'start_pos': 756,
#    'text': 'history',
#    'entities': [['SIO:001196', 1.0228160632095873, 'history']],
#    'best_entity': ('SIO:001196', 1.0228160632095873)},
#   {'end_pos': 777,
#    'start_pos': 772,
#    'text': 'early',
#    'entities': [['PATO:0000694',
#      1.051559949906515,
#      'advanced premature natural precocious starts start early time reference quality process earlier']],
#    'best_entity': ('PATO:0000694', 1.051559949906515)},
#   {'end_pos': 890,
#    'start_pos': 881,
#    'text': 'incidence',
#    'entities': [['PATO:0000057',
#      0.9616609664457924,
#      'inhering virtue single occurrence temporal quality process incidence bearer'],
#     ['STATO:0000413',
#      0.04808533121969688,
#      'new risk number disease incidence cases divided persons ratio']],
#    'best_entity': ('PATO:0000057', 0.9616609664457924)},
#   {'end_pos': 901,
#    'start_pos': 892,
#    'text': 'morbidity',
#    'entities': [['PATO:0001415',
#      1.029298149548129,
#      'members quality proportion virtue given ill inhering time population morbidity']],
#    'best_entity': ('PATO:0001415', 1.029298149548129)},
#   {'start_pos': 907,
#    'text': 'mortality',
#    'end_pos': 916,
#    'entities': [['EFO:0004352',
#      0.8166378370303966,
#      'deaths mortality rate number quantification population measurement'],
#     ['STATO:0000414',
#      0.2041668885470596,
#      'formed   deaths mortality total number disease divided population ratio size']],
#    'best_entity': ('EFO:0004352', 0.8166378370303966)},
#   {'start_pos': 924,
#    'text': 'disease',
#    'end_pos': 931,
#    'entities': [['EFO:0000408', 0.9996333904821858, 'disease'],
#     ['DOID:4', 0.011105514281862166, 'disease'],
#     ['OGMS:0000031',
#      0.0001371020740295387,
#      'disorders processes disposition pathological organism exists ii disease undergo'],
#     ['SIO:010299', 0.00013710511459089092, 'disease']],
#    'best_entity': ('EFO:0000408', 0.9996333904821858)},
#   {'start_pos': 953,
#    'text': 'immunodeficiency syndrome',
#    'end_pos': 978,
#    'entities': [['MONDO:0003778',
#      1.0294009042075567,
#      'adequate response syndrome deficiency syndromes unable disorder immunological antibody mount hypoimmunity primary immunodeficiency immunologic disease system immune'],
#     ['MONDO:0021094',
#      0.5852739575694704,
#      'syndrome mechanisms deficiency disorder defect immunodeficiency immunity humoral cellular disease immuno']],
#    'best_entity': ('MONDO:0003778', 1.0294009042075567)},
#   {'end_pos': 1000,
#    'start_pos': 993,
#    'text': 'elderly',
#    'entities': [['UBERON:0007222',
#      1.036120069548458,
#      'adult late geriatric elderly stage']],
#    'best_entity': ('UBERON:0007222', 1.036120069548458)},
#   {'text': 'blood',
#    'end_pos': 1051,
#    'start_pos': 1046,
#    'entities': [['UBERON:0000178',
#      0.7013146627443836,
#      'fluid vertebrate plasma blood erythrocytes portion composed'],
#     ['EFO:0000296', 0.07792514753409055, 'blood'],
#     ['MA:0000059', 0.07792514753409055, 'blood'],
#     ['ZFA:0000007',
#      0.1558459747850404,
#      'mixture nutrients removes cells blood complex delivers wastes suspended matrix liquid']],
#    'best_entity': ('UBERON:0000178', 0.7013146627443836)},
#   {'start_pos': 1097,
#    'text': 'mode',
#    'end_pos': 1101,
#    'entities': [['SIO:001111', 0.514661914977238, 'mode'],
#     ['STATO:0000033',
#      0.5146505013904231,
#      'corresponds occurring set frequently item number data mode numbers']],
#    'best_entity': ('SIO:001111', 0.514661914977238)},
#   {'start_pos': 1125,
#    'end_pos': 1132,
#    'text': 'elderly',
#    'entities': [['UBERON:0007222',
#      1.036120069548458,
#      'adult late geriatric elderly stage']],
#    'best_entity': ('UBERON:0007222', 1.036120069548458)},
#   {'start_pos': 1139,
#    'end_pos': 1147,
#    'text': 'acquired',
#    'entities': [['MONDO:0021141',
#      1.0361258141587468,
#      'genetically acquired inherited']],
#    'best_entity': ('MONDO:0021141', 1.0361258141587468)},
#   {'start_pos': 1223,
#    'end_pos': 1230,
#    'text': 'elderly',
#    'entities': [['UBERON:0007222',
#      1.036120069548458,
#      'adult late geriatric elderly stage']],
#    'best_entity': ('UBERON:0007222', 1.036120069548458)},
#   {'text': 'major',
#    'end_pos': 1241,
#    'start_pos': 1236,
#    'entities': [['NCBITaxon:1925465', 1.029323829954476, 'major']],
#    'best_entity': ('NCBITaxon:1925465', 1.029323829954476)},
#   {'start_pos': 1424,
#    'end_pos': 1431,
#    'text': 'elderly',
#    'entities': [['UBERON:0007222',
#      1.036120069548458,
#      'adult late geriatric elderly stage']],
#    'best_entity': ('UBERON:0007222', 1.036120069548458)},
#   {'end_pos': 1503,
#    'start_pos': 1498,
#    'text': 'major',
#    'entities': [['NCBITaxon:1925465', 1.029323829954476, 'major']],
#    'best_entity': ('NCBITaxon:1925465', 1.029323829954476)}],
#  [{'end_pos': 68,
#    'start_pos': 59,
#    'text': 'treatment',
#    'entities': [['EFO:0000727', 1.0062476816811299, 'treatment']],
#    'best_entity': ('EFO:0000727', 1.0062476816811299)},
#   {'text': 'disease',
#    'start_pos': 76,
# ...
#     ['GO:0009405',
#      0.12690617282445138,
#      'detrimental abnormal induce pathogenesis processes virulence organism ability state set generate specific generally']],
#    'best_entity': ('GO:0044003', 33.517033048277085)},
#   {'text': 'presence',
#    'start_pos': 818,
#    'end_pos': 826,
#    'entities': [['PATO:0000070',
#      1.0108983624365302,
#      'quantitative type presence number organism count absence entities']],
#    'best_entity': ('PATO:0000070', 1.0108983624365302)},
#   {'start_pos': 850,
#    'text': 'coinfection',
#    'end_pos': 861,
#    'entities': [['EFO:0010716',
#      1.056721385892723,
#      'multiple coinfection species simultaneous pathogen host infection']],
#    'best_entity': ('EFO:0010716', 1.056721385892723)},
#   {'end_pos': 884,
#    'text': 'viruses',
#    'start_pos': 877,
#    'entities': [['NCBITaxon:10239', 1.002397948148497, 'viruses']],
#    'best_entity': ('NCBITaxon:10239', 1.002397948148497)},
#   {'start_pos': 985,
#    'text': 'lymphoma',
#    'end_pos': 993,
#    'entities': [['EFO:0000574',
#      0.9812764429957627,
#      'respect cell cells lymphoid lymphomatous therapy non malignant clinical reed characteristic heterogeneous nos lymphomas tumors course prognosis mlym sternberg absence lymphoma group cancer feature hodgkin tissue lineage disease giant common differ'],
#     ['MONDO:0003659',
#      0.047723836966210104,
#      'hodgkin pediatric occurs non childhood lymphoma'],
#     ['MONDO:0003660', 0.02386202596409236, 'adults adult occurs lymphoma'],
#     ['DOID:0060058', 0.06363249917469749, 'lymphoma']],
#    'best_entity': ('EFO:0000574', 0.9812764429957627)},
#   {'start_pos': 1035,
#    'text': 'population',
#    'end_pos': 1045,
#    'entities': [['OBI:0000181',
#      0.9819809294734902,
#      'collection sampled site individuals particular counted population class taxonomic area living'],
#     ['SIO:001061', 0.07014307464880153, 'population']],
#    'best_entity': ('OBI:0000181', 0.9819809294734902)},
#   {'start_pos': 1069,
#    'end_pos': 1077,
#    'text': 'advanced',
#    'entities': [['PATO:0000694',
#      1.0231241573529883,
#      'advanced premature natural precocious starts start early time reference quality process earlier']],
#    'best_entity': ('PATO:0000694', 1.0231241573529883)},
#   {'end_pos': 1083,
#    'start_pos': 1078,
#    'text': 'stage',
#    'entities': [['UBERON:0000105',
#      1.0097686041539875,
#      'life cycle spatiotemporal region organism developmental encompassing stage']],
#    'best_entity': ('UBERON:0000105', 1.0097686041539875)},
#   {'text': 'aggressive',
#    'end_pos': 1095,
#    'start_pos': 1085,
#    'entities': [['EFO:0002752', 1.0328239241722659, 'aggressive']],
#    'best_entity': ('EFO:0002752', 1.0328239241722659)},
#   {'start_pos': 1125,
#    'end_pos': 1132,
#    'text': 'disease',
#    'entities': [['EFO:0000408', 0.9996296346737189, 'disease'],
#     ['DOID:4', 0.011105472556380638, 'disease'],
#     ['OGMS:0000031',
#      0.00013710212925410918,
#      'disorders processes disposition pathological organism exists ii disease undergo'],
#     ['SIO:010299', 0.00013710459946148935, 'disease']],
#    'best_entity': ('EFO:0000408', 0.9996296346737189)},
#   {'text': 'infection',
#    'end_pos': 1319,
#    'start_pos': 1310,
#    'entities': [['EFO:0000544', 0.6820996691266934, 'infection'],
#     ['EFO:0005741',
#      219.6204474943703,
#      'indirect direct diseases viral presence agent infectious disorder manifestations clinical parasitic resulting activity microbial transmitted disease communicable contact transmissible infection']],
#    'best_entity': ('EFO:0005741', 219.6204474943703)},
#   {'start_pos': 1371,
#    'text': 'cancer',
#    'end_pos': 1377,
#    'entities': [['EFO:0000311',
#      1.0001055795077414,
#      'cell neoplasms sarcomas anatomic cells non excision squamous malignant malignancy composed mt distant lymphomas pleomorphic neoplastic adenocarcinomas neoplasia primary tissues organ melanomas atypical carcinomas tumour type growth sites cancer hodgkin neoplasm recur metastasize leukemias disease invade tumor system common'],
#     ['DOID:162', 0.10002936935322221, 'cancer'],
#     ['NCBITaxon:6754', 0.011431927926082537, 'cancer'],
#     ['PDO:000277', 0.0009526606605068781, 'cancer']],
#    'best_entity': ('EFO:0000311', 1.0001055795077414)},
#   {'end_pos': 1387,
#    'text': 'treatment',
#    'start_pos': 1378,
#    'entities': [['EFO:0000727', 1.0060210478056824, 'treatment']],
#    'best_entity': ('EFO:0000727', 1.0060210478056824)},
#   {'end_pos': 1419,
#    'text': 'infection',
#    'start_pos': 1410,
#    'entities': [['EFO:0000544', 0.6820996691266934, 'infection'],
#     ['EFO:0005741',
#      219.6204474943703,
#      'indirect direct diseases viral presence agent infectious disorder manifestations clinical parasitic resulting activity microbial transmitted disease communicable contact transmissible infection']],
#    'best_entity': ('EFO:0005741', 219.6204474943703)},
#   {'text': 'recent',
#    'end_pos': 1487,
#    'start_pos': 1481,
#    'entities': [['PATO:0001484',
#      1.0328099677447629,
#      'near present long occurs recent quality process']],
#    'best_entity': ('PATO:0001484', 1.0328099677447629)},
#   {'start_pos': 1621,
#    'end_pos': 1627,
#    'text': 'cancer',
#    'entities': [['EFO:0000311',
#      1.0001055795077414,
#      'cell neoplasms sarcomas anatomic cells non excision squamous malignant malignancy composed mt distant lymphomas pleomorphic neoplastic adenocarcinomas neoplasia primary tissues organ melanomas atypical carcinomas tumour type growth sites cancer hodgkin neoplasm recur metastasize leukemias disease invade tumor system common'],
#     ['DOID:162', 0.10002936935322221, 'cancer'],
#     ['NCBITaxon:6754', 0.011431927926082537, 'cancer'],
#     ['PDO:000277', 0.0009526606605068781, 'cancer']],
#    'best_entity': ('EFO:0000311', 1.0001055795077414)}],
#  [{'text': 'disease',
#    'start_pos': 21,
#    'end_pos': 28,
#    'entities': [['EFO:0000408', 0.999658306481246, 'disease'],
#     ['DOID:4', 0.011105791088325458, 'disease'],
#     ['OGMS:0000031',
#      0.00013710640382571813,
#      'disorders processes disposition pathological organism exists ii disease undergo'],
#     ['SIO:010299', 0.00013710853195463528, 'disease']],
#    'best_entity': ('EFO:0000408', 0.999658306481246)},
#   {'end_pos': 198,
#    'text': 'life',
#    'start_pos': 194,
#    'entities': [['UBERON:0000104',
#      1.038624632800934,
#      'span commencing zygote life cycle ending death organism lifespan entire stage']],
#    'best_entity': ('UBERON:0000104', 1.038624632800934)},
#   {'end_pos': 284,
#    'start_pos': 279,
#    'text': 'light',
#    'entities': [['CHEBI:30212',
#      0.34619679364461553,
#      'quantum 1 c nu photon momentum particle lichtquant force carrier h electromagnetic planck light gamma spin mass speed zero energy rest charge radiation foton hnu frequency number constant'],
#     ['EFO:0000568',
#      0.34621022598990403,
#      'restricted wavelength natural exposure type e.g. photoperiod light'],
#     ['PATO:0000665',
#      0.34621224111834,
#      'relatively brightness color light high']],
#    'best_entity': ('PATO:0000665', 0.34621224111834)},
#   {'text': 'approaches',
#    'start_pos': 351,
#    'end_pos': 361,
#    'entities': [['PATO:0002259',
#      1.0445079053573856,
#      'quality close virtue adjacent inhering relation near entity vicinity approaches located spatial space bearer']],
#    'best_entity': ('PATO:0002259', 1.0445079053573856)},
#   {'start_pos': 439,
#    'end_pos': 447,
#    'text': 'solution',
#    'entities': [['CHEBI:75958',
#      1.0549452851943257,
#      'scattered role mixture playing solute solution aggregates molecular homogeneous chemical solvent']],
#    'best_entity': ('CHEBI:75958', 1.0549452851943257)},
#   {'start_pos': 508,
#    'text': 'measuring',
#    'end_pos': 517,
#    'entities': [['OBI:0000070',
#      0.9981283322853133,
#      'produce material examining information physically evaluant entity objective planned proxies process assay'],
#     ['SIO:001054', 0.0018501584129673107, 'measuring']],
#    'best_entity': ('OBI:0000070', 0.9981283322853133)},
#   {'start_pos': 574,
#    'text': 'true',
#    'end_pos': 578,
#    'entities': [['SIO:000269', 1.054965753252453, 'true']],
#    'best_entity': ('SIO:000269', 1.054965753252453)},
#   {'text': 'test',
#    'end_pos': 583,
#    'start_pos': 579,
#    'entities': [['UBERON:0006611',
#      1.0549493786104516,
#      'insects shell lorica test turtles crustaceans mollusks including exoskeleton']],
#    'best_entity': ('UBERON:0006611', 1.0549493786104516)},
#   {'end_pos': 632,
#    'start_pos': 627,
#    'text': 'virus',
#    'entities': [['NCBITaxon:10239', 0.9909890681841299, 'viruses'],
#     ['SIO:010379', 0.009045975573996473, 'virus']],
#    'best_entity': ('NCBITaxon:10239', 0.9909890681841299)},
#   {'start_pos': 687,
#    'text': 'treatment',
#    'end_pos': 696,
#    'entities': [['EFO:0000727', 1.0099966856429352, 'treatment']],
#    'best_entity': ('EFO:0000727', 1.0099966856429352)},
#   {'text': 'associated',
#    'start_pos': 717,
#    'end_pos': 727,
#    'entities': [['PATO:0001668',
#      1.0445139845865647,
#      'quality close virtue interacting inhering physically entity proximity structural associated bearer']],
#    'best_entity': ('PATO:0001668', 1.0445139845865647)},
#   {'start_pos': 790,
#    'end_pos': 795,
#    'text': 'major',
#    'entities': [['NCBITaxon:1925465', 1.0445342502565014, 'major']],
#    'best_entity': ('NCBITaxon:1925465', 1.0445342502565014)},
#   {'text': 'approaches',
#    'end_pos': 806,
#    'start_pos': 796,
#    'entities': [['PATO:0002259',
#      1.0445079053573856,
#      'quality close virtue adjacent inhering relation near entity vicinity approaches located spatial space bearer']],
#    'best_entity': ('PATO:0002259', 1.0445079053573856)},
#   {'end_pos': 817,
#    'start_pos': 811,
#    'text': 'recent',
#    'entities': [['PATO:0001484',
#      1.0549534721243232,
#      'near present long occurs recent quality process']],
#    'best_entity': ('PATO:0001484', 1.0549534721243232)}],
#  [{'text': 'reduced',
#    'start_pos': 59,
#    'end_pos': 66,
#    'entities': [['PATO:0000587',
#      0.6186287161006213,
#      'low reduced decreased relatively tiny small quality underdeveloped hypoplasia size'],
#     ['PATO:0001997',
#      0.4124191440670809,
#      'low reduced decreased relatively subnumerary fewer present number organism numbers']],
#    'best_entity': ('PATO:0000587', 0.6186287161006213)},
#   {'end_pos': 80,
#    'start_pos': 71,
#    'text': 'morbidity',
#    'entities': [['PATO:0001415',
#      1.0438395434772825,
#      'members quality proportion virtue given ill inhering time population morbidity']],
#    'best_entity': ('PATO:0001415', 1.0438395434772825)},
#   {'start_pos': 85,
#    'text': 'mortality',
#    'end_pos': 94,
#    'entities': [['EFO:0004352',
#      0.8248448377898527,
#      'deaths mortality rate number quantification population measurement'],
#     ['STATO:0000414',
#      0.2062090262427037,
#      'formed   deaths mortality total number disease divided population ratio size']],
#    'best_entity': ('EFO:0004352', 0.8248448377898527)},
#   {'text': 'infection',
#    'start_pos': 114,
#    'end_pos': 123,
#    'entities': [['EFO:0000544', 0.6920433563128887, 'infection'],
#     ['EFO:0005741',
#      220.40472480956862,
#      'indirect direct diseases viral presence agent infectious disorder manifestations clinical parasitic resulting activity microbial transmitted disease communicable contact transmissible infection']],
#    'best_entity': ('EFO:0005741', 220.40472480956862)},
#   {'text': 'cell',
#    'end_pos': 206,
#    'start_pos': 202,
#    'entities': [['CL:0000000', 0.9951976191778338, 'cell'],
#     ['GO:0005623', 0.4900490345468782, 'cell'],
#     ['SIO:010001', 0.004118059113839313, 'cell'],
#     ['ZFA:0009000',
#      0.5209116825193252,
#      'cell anatomical maximally structure plasma cells surrounded parts membrane connected compartment']],
#    'best_entity': ('CL:0000000', 0.9951976191778338)},
#   {'start_pos': 267,
#    'end_pos': 280,
#    'text': 'proliferation',
#    'entities': [['UBERON:2000098',
#      0.34625620114657396,
#      'proliferation cell cycle region proliferative division'],
#     ['ZFA:0000098',
#      4.160418032613466,
#      'rapidly cell proliferation cycle anatomical cluster region dividing cells proliferative division consists']],
#    'best_entity': ('ZFA:0000098', 4.160418032613466)},
#   {'end_pos': 289,
#    'start_pos': 284,
#    'text': 'cells',
#    'entities': [['ZFA:0009000',
#      1.001964687484401,
#      'cell anatomical maximally structure plasma cells surrounded parts membrane connected compartment']],
#    'best_entity': ('ZFA:0009000', 1.001964687484401)},
#   {'start_pos': 310,
#    'text': 'initiation',
#    'end_pos': 320,
#    'entities': [['PATO:0002325',
#      1.0250367382392522,
#      'relation respect temporal onset start initiation reference quality process']],
#    'best_entity': ('PATO:0002325', 1.0250367382392522)},
#   {'end_pos': 355,
#    'start_pos': 347,
#    'text': 'residual',
#    'entities': [['STATO:0000234',
#      1.0541072644825578,
#      'fitting observable error residual item output estimate unobservable data model process']],
#    'best_entity': ('STATO:0000234', 1.0541072644825578)},
#   {'start_pos': 439,
#    'end_pos': 443,
#    'text': 'drug',
#    'entities': [['CHEBI:23888',
#      0.9980086471271064,
#      'drug abused taken absorbed modify substance organism commonly medicine term drugs substances therapeutic accepted functions generally living purpose'],
#     ['SIO:010038', 0.01506495930959335, 'drug']],
#    'best_entity': ('CHEBI:23888', 0.9980086471271064)},
#   {'text': 'resistance',
#    'end_pos': 454,
#    'start_pos': 444,
#    'entities': [['PATO:0001046',
#      1.0236110416433104,
#      'inhering stimulus virtue resistance resist disposition quality bearer']],
#    'best_entity': ('PATO:0001046', 1.0236110416433104)},
#   {'end_pos': 563,
#    'text': 'sequence',
#    'start_pos': 555,
#    'entities': [['SIO:001118', 1.0541351660171256, 'sequence']],
#    'best_entity': ('SIO:001118', 1.0541351660171256)},
#   {'end_pos': 682,
#    'start_pos': 677,
#    'text': 'major',
#    'entities': [['NCBITaxon:1925465', 1.0438644103478931, 'major']],
#    'best_entity': ('NCBITaxon:1925465', 1.0438644103478931)},
#   {'start_pos': 693,
#    'end_pos': 697,
#    'text': 'drug',
#    'entities': [['CHEBI:23888',
#      0.9980086471271064,
#      'drug abused taken absorbed modify substance organism commonly medicine term drugs substances therapeutic accepted functions generally living purpose'],
#     ['SIO:010038', 0.01506495930959335, 'drug']],
#    'best_entity': ('CHEBI:23888', 0.9980086471271064)},
#   {'start_pos': 698,
#    'text': 'resistant',
#    'end_pos': 707,
#    'entities': [['PATO:0000513',
#      0.5219197717386411,
#      'resistant inhering stimulus virtue sensitivity lacking quality external bearer insensitive'],
#     ['PATO:0001178',
#      2.1370335860459315,
#      'resistant inhering stimulus virtue resistance quality bearer']],
#    'best_entity': ('PATO:0001178', 2.1370335860459315)},
#   {'end_pos': 715,
#    'text': 'viruses',
#    'start_pos': 708,
#    'entities': [['NCBITaxon:10239', 1.003918298003014, 'viruses']],
#    'best_entity': ('NCBITaxon:10239', 1.003918298003014)},
#   {'text': 'variable',
#    'end_pos': 801,
#    'start_pos': 793,
#    'entities': [['PATO:0001227',
#      0.7687755188760317,
#      'variation inhering virtue variable variability exhibits quality change variant bearer'],
#     ['SIO:000367', 0.768793833033103, 'variable'],
#     ['STATO:0000258',
#      1.6656758822131044,
#      'agent determined item occuring set assume data values observation randomly variable']],
#    'best_entity': ('STATO:0000258', 1.6656758822131044)},
#   {'text': 'fitness',
#    'start_pos': 802,
#    'end_pos': 809,
#    'entities': [['SIO:000357', 1.0541351660171256, 'fitness']],
#    'best_entity': ('SIO:000357', 1.0541351660171256)},
#   {'text': 'genetic',
#    'end_pos': 867,
#    'start_pos': 860,
#    'entities': [['MONDO:0021152',
#      1.054110054477236,
#      'constitutitional problem inherited genetic characteristic parents familial hereditary disease cause']],
#    'best_entity': ('MONDO:0021152', 1.054110054477236)}]]
